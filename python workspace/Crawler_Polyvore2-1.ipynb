# %% [markdown]
# # Polyvore Crawler for Storing to DB

# %%
# %matplotlib inline
import matplotlib
from matplotlib import pyplot as plt
import os
import time
import cv2
import json
import requests
from requests.exceptions import *
import psycopg2
import shutil
from PIL import Image
from lxml import html
from bs4 import BeautifulSoup
from datetime import date, datetime
import numpy as np
from numpy import *
from pylab import *
import pandas
from pandas import Series, DataFrame
import multiprocessing

# %%
# Connect to postgres database
conn = psycopg2.connect(database="fashion", user="michellechen", password="", host="127.0.0.1", port="5432")

print "Opened database successfully"

# Connection cursor to database
cur = conn.cursor()

# Create outfit table
cur.execute('''CREATE TABLE IF NOT EXISTS outfits(
                outfit_id INT PRIMARY KEY NOT NULL,
                link TEXT NOT NULL,
                title TEXT,
                image TEXT,
                author TEXT,
                create_date TEXT,
                views INT,
                likes INT,
                description TEXT,
                similar1 TEXT,
                similar2 TEXT,
                similar3 TEXT,
                similar4 TEXT,
                similar5 TEXT
                )''')

# Create outfit_item table
cur.execute('''CREATE TABLE IF NOT EXISTS outfit_item(
                id TEXT PRIMARY KEY NOT NULL,
                outfit_id INT,
                item_id INT
                )''')

# Create outfit item table
cur.execute('''CREATE TABLE IF NOT EXISTS items(
                item_id INT PRIMARY KEY NOT NULL,
                link TEXT NOT NULL,
                title TEXT,
                image TEXT,
                category1_id INT,
                category1_name TEXT,
                category2_id INT,
                category2_name TEXT,
                category3_id INT,
                category3_name TEXT,
                category4_id INT,
                category4_name TEXT,
                brand TEXT,
                price TEXT,
                likes INT,
                description TEXT,
                keyword1 TEXT,
                keyword2 TEXT,
                keyword3 TEXT,
                keyword4 TEXT,
                keyword5 TEXT,
                keyword6 TEXT
                )''')

conn.commit() 

print "Table created successfully"
# Out:
# Opened database successfully
# Table created successfully

# %%
# Headers
head = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'}

# %%
# Crawl item data with item link
def crawl_item(day, outfit_id, line):
    
    # Initialize
    item_id = 0
    item_link = ""
    item_title = ""
    item_image = ""
    item_category_id = [0, 0, 0, 0]
    item_category_name = ["", "", "", ""]
    item_brand = ""
    item_price = ""
    item_likes = 0
    item_description = ""
    item_keywords = ["", "", "", "", "", ""]
    
    # Item id
    item_id = int(line.split('\n')[0].split('=')[-1])
    #print "item id: " + str(item_id)

    # Item link
    item_link = line.split('context_id')[0] + "id=" + str(item_id)
    print "item link: " + item_link
    
    # Get request response
    while True:
        try:
            res = requests.get(item_link, headers = head)
        except RequestException:
            print "Item Request Connection Error!"
            print "Delay 1 minutes!"
            time.sleep(60) # Delay 60 seconds
        else:
            break
    
    # If Item page is not found
    if res.status_code == 404:
        print "HTTP Response Error " + str(res.status_code)
        print "Item Not Found!"
        return 0
    
    # When http response error
    while res.status_code != 200:
        print "HTTP Response Error " + str(res.status_code)
        time.sleep(3) # Delay 3 seconds
        res = requests.get(item_link, headers = head)
        if res.status_code == 200:
            break

    # Parse html with BeautifulSoup
    soup = BeautifulSoup(res.text, "html.parser")
    
    # Item category
    try:
        category = int(soup.select('.crumb')[0].select('a')[0]['href'].split('=')[-1])
    except ValueError: # Not in category
        print "Item Doesn't Have Category ID!"
        return 0
    else:
        if category != 1: # Not in category "Women's Fashion" 
            print "Item Not In Category Women's Fashion!"
            return 0
        else:
            for index, item in enumerate(soup.select('.crumb')):
                try:
                    item_category_id[index] = int(item.select('a')[0]['href'].split('=')[-1])
                    #print str(item_category_id[index])
                except ValueError:
                    pass
                
                item_category_name[index] = item.select('a')[0].select('span')[0].text       
                #print item_category_name[index]

                # Item brand
                if 'brand=' in item.select('a')[0]['href']:
                    item_brand = item.select('a')[0]['href'].split('brand=')[-1].split('&')[0]
                    #print "item brand: " + item_brand
                    
            # Item title
            item_title = soup.find_all('meta', {'property': 'og:title'})[0]['content']
            #print "item title: " + item_title

            # Item image
            item_image = soup.find_all('meta', {'property': 'og:image'})[0]['content']
            #print "item image: " + item_image
            
            # Save Item image as a jpg file
            while True:
                try: 
                    image_res = requests.get(item_image, stream = True)
                except ConnectionError:
                    print "Image Request Connection Error!"
                    time.sleep(3) # Delay 3 seconds
                else:
                    break
                
            f = open('item_images/' + day + '/' + day + '-' + str(outfit_id) + '-'+ str(item_id) + '.jpg', 'wb')
            shutil.copyfileobj(image_res.raw, f)
            f.close

            # Item price
            try: 
                item_price = soup.select('div.bd')[0].select('.price')[0].text
                #print "item price: " + item_price 
            except IndexError:
                try:
                    item_price = soup.select('div.bd')[0].select('.orig_price')[0].text
                    #print "item price: " + item_price 
                except IndexError:
                    pass
           
            # Item likes
            item_likes = int(soup.find_all('meta', {'property': 'polyvore:saves'})[0]['content'])
            #print "item likes: " + str(item_likes)

            # Item description
            try:
                item_description = soup.select('.tease')[0].text
                #print "item description: " + item_description
            except IndexError:
                pass

            # Item keyword 
            try:
                soup.select('#related_searches')[0].select('a')
            except IndexError:
                pass
            else:
                for index, keyword in enumerate(soup.select('#related_searches')[0].select('a')):
                    if index >= 6:
                        break
                    item_keywords[index] = keyword.text
            #print "item keywords: " + item_keywords
            
           
        
            ############################# Insert item data into database ###############################
            
            # Insert item data into items table
            query = '''INSERT INTO items
                        (item_id, link, title, image, category1_id, category1_name, category2_id, category2_name,
                        category3_id, category3_name, category4_id, category4_name, brand, price, likes,
                        description, keyword1, keyword2, keyword3, keyword4, keyword5, keyword6) 
                        VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);'''
            data = (item_id, item_link, item_title, item_image, item_category_id[0], item_category_name[0], 
                    item_category_id[1], item_category_name[1], item_category_id[2], item_category_name[2],
                    item_category_id[3], item_category_name[3], item_brand, item_price, item_likes, item_description, 
                    item_keywords[0], item_keywords[1], item_keywords[2], item_keywords[3], item_keywords[4], 
                    item_keywords[5])

            try:
                cur.execute(query, data)
            except psycopg2.Error, e:
                print "Item pass!"
                print e.pgerror
                pass

            conn.commit()
            
            
            ########################## Insert outfit-item data into database ###########################

            # Insert outfit-item pairing data into outfit-item table
            pairing_query =  '''INSERT INTO outfit_item (id, outfit_id, item_id) 
                                VALUES(%s, %s, %s);'''
            pairing_data = (str(outfit_id) + "-" + str(item_id), outfit_id, item_id)

            try:
                cur.execute(pairing_query, pairing_data)
            except psycopg2.Error, e:
                print "Outfit-Item pass!"
                print e.pgerror
                pass

            conn.commit()
           
    return 1

# %%
# Crawl outfit data with outfit link
def crawl_outfit (day, line):
  
    # Initialize 
    outfit_link = ""
    outfit_id = 0
    outfit_title = ""
    outfit_image = ""
    outfit_author = ""
    outfit_date = ""
    outfit_views = 0
    outfit_likes = 0
    outfit_description = ""
    outfit_similars = []

    # Get request response
    while True:
        try:
            res = requests.get(line, headers = head)
        except RequestException:
            print "Outfit Request Connection Error!"
            print "Delay 1 minutes!"
            time.sleep(60) # Delay 60 seconds
        else:
            break

    # If outfit page is not found
    if res.status_code == 404:
        # Skip to next outfit
        print "HTTP Response Error " + str(res.status_code)
        print "Outfit Not Found!"
        return
    
    # When http response error
    while res.status_code != 200:
        # Print error code
        print "HTTP Response Error " + str(res.status_code)
        # Delay 3 seconds
        time.sleep(3) 
        # Requests again
        res = requests.get(line, headers = head) 
        if res.status_code == 200:
            break

    # Parse html with BeautifulSoup
    soup = BeautifulSoup(res.text, "html.parser")

    # Outfit link
    outfit_link = line.split('\n')[0]
    print "outfit link: " + outfit_link

    # Outfit id
    outfit_id = int(outfit_link.split('/')[-1].split('=')[-1])
    #print "outfit id: " + str(outfit_id)

    # Outfit title
    outfit_title = soup.find_all('meta', {'property': 'og:title'})[0]['content']
    #print "outfit title: " + outfit_title

    # Outfit image
    outfit_image = soup.find_all('meta', {'property': 'og:image'})[0]['content']
    #print "outfit image: " + outfit_image

    # Save outfit image as a jpg file
    while True:
        try: 
            image_res = requests.get(outfit_image, stream = True)
        except ConnectionError:
            print "Image Request Connection Error!"
            time.sleep(3) # Delay 3 seconds
            continue
        break

    f = open('outfit_images/' + day + '/' + day + '-' + str(outfit_id) + '.jpg', 'wb')
    shutil.copyfileobj(image_res.raw, f)
    f.close

    # Outfit author link
    outfit_author = soup.find_all('meta', {'property': 'polyvore:author'})[0]['content']
    #print "outfit author: " + outfit_author

    # Outfit create time
    outfit_date = day
    #print "outfit create: " + outfit_date

    # Outfit views count
    outfit_views = int(str(soup.select('div.meta')[0].select('div')[-1])[5:-7].split('.')[1].split()[0].replace(',', ''))
    #print "outfit views: " + str(outfit_views)

    # Outfit likes count
    outfit_likes = int(soup.find_all('meta', {'property': 'polyvore:likes'})[0]['content'])
    #print "outfit likes: " + str(outfit_likes)

    # Outfit description
    outfit_description = soup.select('div.bd')[0].select('img')[0]['alt']
    #print "outfit description: " + outfit_description

    # Outfit similar style
    for grid in soup.select('.grid_item.hover_container.type_set.span2w.span2h'):
        for main in grid.select('div.main'):
            outfit_similars.append('http://www.polyvore.com/' + main.select('a')[0]['href'][3:])

    # If similar outfits do not have 5 outfits, append empty one
    if len(outfit_similars) != 5:
        for i in xrange(5 - len(outfit_similars)):
            outfit_similars.append("")

#         for i in xrange(len(outfit_similars)):
#             print "outfit similar " + str(i) + ": " + outfit_similars[i]     



    ############################# Insert outfit data into database #############################    

    # Insert outfit data into outfit table
    outfit_query = '''INSERT INTO outfits 
                        (outfit_id, link, title, image, author, create_date, views, likes, 
                        description, similar1, similar2, similar3, similar4, similar5) 
                        VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);'''
    outfit_data = (outfit_id, outfit_link, outfit_title, outfit_image, outfit_author, outfit_date, 
            outfit_views, outfit_likes, outfit_description, 
            outfit_similars[0], outfit_similars[1], outfit_similars[2], outfit_similars[3], outfit_similars[4])

    try:
        cur.execute(outfit_query, outfit_data)
    except psycopg2.Error, e:
        print "Outfit pass!"
        print e.pgerror
        pass

    conn.commit()


    #################################### Items in the outfit ###################################

    # initialize
    item_count = 0
    item_link = []   

    # Outfit set_item grid
    done = False
    for grid in soup.select('.grid_item.hover_container.type_thing.span1w.span1h'):
        for main in grid.select('div.main'): 

            print "item" + str(item_count)

            item_link.append('http://www.polyvore.com/' + main.select('a')[0]['href'][3:])
            #print "item link " + str(item_count) + ": " + item_link[item_count]

            # Crawl item data, if item is not in category, then next item is not too
            if crawl_item(day, outfit_id, item_link[item_count]) == 0:

                # If first item is not in category, the outfit is not a fashion outfit
                if item_count == 0:

                    print "Remove outfit!"
                    # Delete this outfit row in outfit table
                    outfit_delete = '''DELETE FROM outfits 
                                        WHERE outfit_id = ''' + str(outfit_id) + ''';'''
                    cur.execute(outfit_delete)
                    conn.commit()

                    # Remove this outfit image file
                    os.remove('outfit_images/' + day + '/' + day + '-' + str(outfit_id) + '.jpg')

                done = True
                break # Break the inner for loop

            item_count += 1

#         # If done is true, we do not need to run the next item
        if done: 
            break # Break the outer for loop
       
    return

# %%
# Crawler for all outfits and items in one day
def crawler(day):

    # Create new folder with day name for storing outfit images
    if not os.path.exists('outfit_images/' + day):
        os.makedirs('outfit_images/' + day)

    # Create new folder with day name for storing item images
    if not os.path.exists('item_images/' + day):
        os.makedirs('item_images/' + day)
    
    # Initialize
    outfit_count = 0

    # Open the file
    with open('outfit_links/Today_Outfit_Links_'+ day +'.txt', 'r') as f:
        
        # Read every links in this txt file
        for line in f.readlines():
            
            print "outfit" + str(outfit_count)
            
            if outfit_count != 0 and outfit_count % 50 == 0:
                print "Delay 1 minute!"
                time.sleep(60) # Delay 60 seconds

            # Crawl outfit
            crawl_outfit(day, line)

            print "\n"
            outfit_count += 1
            
    return

# %%
day = '20171230'

crawler(day)

# Close the connection to database
cur.close()
conn.close()

print "END!"
# Out:
# outfit0
# outfit link: https://www.polyvore.com/boho_style/set?id=232911733
# Outfit pass!
# ERROR:  duplicate key value violates unique constraint "outfits_pkey"
# DETAIL:  Key (outfit_id)=(232911733) already exists.
#
# item0
# item link: http://www.polyvore.com/chunky_heel_lace_up_knee/thing?id=222173854
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222173854) already exists.
#
# item1
# item link: http://www.polyvore.com/amigos_de_hoy_jethro_bag/thing?id=215070346
# item2
# item link: http://www.polyvore.com/sweet_romance_boho_pearl_vintage/thing?id=190186845
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(190186845) already exists.
#
# item3
# item link: http://www.polyvore.com/sweet_romance_boho_pearl_vintage/thing?id=139055275
# item4
# item link: http://www.polyvore.com/grass_spray_orange/thing?id=145276315
# Item Doesn't Have Category ID!
#
#
# outfit1
# outfit link: https://www.polyvore.com/in_jungle/set?id=232910069
# item0
# item link: http://www.polyvore.com/theory_clairene_leopard-print_faux_fur/thing?id=216933268
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216933268) already exists.
#
# item1
# item link: http://www.polyvore.com/alexander_mcqueen_bi-color_sculpted_heel/thing?id=218872344
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218872344) already exists.
#
# item2
# item link: http://www.polyvore.com/pre-owned_dolce_gabbana_sicily_velvet/thing?id=220411383
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220411383) already exists.
#
# item3
# item link: http://www.polyvore.com/sydney_black_halterneck_deep_bodysuit/thing?id=230014826
# item4
# item link: http://www.polyvore.com/gold_glitter_background_vector_image/thing?id=221163601
# Item Doesn't Have Category ID!
#
#
# outfit2
# outfit link: https://www.polyvore.com/aint_poppin_jk/set?id=232920396
# item0
# item link: http://www.polyvore.com/gcds_graphic_logo_cropped_sweatshirt/thing?id=221244475
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221244475) already exists.
#
# item1
# item link: http://www.polyvore.com/striped_flare_pants/thing?id=229038075
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229038075) already exists.
#
# item2
# item link: http://www.polyvore.com/yeezy_black_stretch_canvas_lace-up/thing?id=206422280
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(206422280) already exists.
#
# item3
# item link: http://www.polyvore.com/yellow_punk_style_metal_full/thing?id=228553565
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228553565) already exists.
#
#
#
# outfit3
# outfit link: https://www.polyvore.com/polypresents_new_years_resolutions/set?id=232910748
# item0
# item link: http://www.polyvore.com/high_waist_single_breasted_long/thing?id=226388852
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226388852) already exists.
#
# item1
# item link: http://www.polyvore.com/womens_nike_fleece_pants/thing?id=184088465
# item2
# item link: http://www.polyvore.com/nike_womens_pro_training_shorts/thing?id=230055747
# item3
# item link: http://www.polyvore.com/nike_zoom_winflo_fierce_purple/thing?id=200683550
# item4
# item link: http://www.polyvore.com/purple_cable_knit_beret_hat/thing?id=209101400
# item5
# item link: http://www.polyvore.com/nike_dri_fit_womens_tempo/thing?id=225685068
# item6
# item link: http://www.polyvore.com/polypresents/thing?id=227027354
# Item Doesn't Have Category ID!
#
#
# outfit4
# outfit link: https://www.polyvore.com/cute_cozy_winter_style/set?id=232916264
# item0
# item link: http://www.polyvore.com/splendid_venice_striped_stretch-jersey_turtleneck/thing?id=223431942
# item1
# item link: http://www.polyvore.com/peacoat/thing?id=92454267
# item2
# item link: http://www.polyvore.com/prana_imogen_hooded_vest/thing?id=220669241
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220669241) already exists.
#
# item3
# item link: http://www.polyvore.com/dsquared2_distressed_rolled_cuff_jeans/thing?id=228156289
# item4
# item link: http://www.polyvore.com/cole_haan_avalon_tall_boot/thing?id=98337850
# item5
# item link: http://www.polyvore.com/tassel_wood_bead_shoulder_bag/thing?id=229000109
# item6
# item link: http://www.polyvore.com/kate_spade_new_york_light/thing?id=127401740
# item7
# item link: http://www.polyvore.com/vivienne_westwood_tartan_blanket_wool/thing?id=119149417
#
#
# outfit5
# outfit link: https://www.polyvore.com/untitled_1136/set?id=232922532
# item0
# item link: http://www.polyvore.com/world_sucks_crop_top/thing?id=124842140
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(124842140) already exists.
#
# item1
# item link: http://www.polyvore.com/high_waisted_rainbow_colorful_tie/thing?id=135076296
# item2
# item link: http://www.polyvore.com/womens_converse_chuck_taylor_all/thing?id=209981457
# item3
# item link: http://www.polyvore.com/tic_tac_big_pack_fruit/thing?id=105120223
# Item Doesn't Have Category ID!
#
#
# outfit6
# outfit link: https://www.polyvore.com/untitled_329/set?id=232920400
# item0
# item link: http://www.polyvore.com/viktor_rolf_archive_na_red/thing?id=32025682
# item1
# item link: http://www.polyvore.com/love_moschino_coat/thing?id=174533603
# item2
# item link: http://www.polyvore.com/pu_skirt_oh_my_love/thing?id=160114862
# item3
# item link: http://www.polyvore.com/alexander_mcqueen_236731j330n_plexi_blue/thing?id=15398780
# item4
# item link: http://www.polyvore.com/hot_hmm_rita_ora_capital/thing?id=145346773
# Item Doesn't Have Category ID!
#
#
# outfit7
# outfit link: https://www.polyvore.com/untitled_1129/set?id=232922316
# item0
# item link: http://www.polyvore.com/paint_drip_skew_collar_sweatshirt/thing?id=190165723
# item1
# item link: http://www.polyvore.com/moto_90s_bleach_super_rip/thing?id=167820266
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(167820266) already exists.
#
# item2
# item link: http://www.polyvore.com/newest_converse_chuck_taylor_all/thing?id=146398275
# item3
# item link: http://www.polyvore.com/punk_canvas_uk_us_flag/thing?id=66179568
#
#
# outfit8
# outfit link: https://www.polyvore.com/teen_queen/set?id=232918198
# item0
# item link: http://www.polyvore.com/marchesa_notte_embroidered_floral-appliqu%C3%A9d_gown/thing?id=218598243
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218598243) already exists.
#
# item1
# item link: http://www.polyvore.com/purple_pointed_out_ankle_strap/thing?id=172376779
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(172376779) already exists.
#
# item2
# item link: http://www.polyvore.com/jeffrey_levinson_womens_elina_clutch/thing?id=227040882
# item3
# item link: http://www.polyvore.com/womens_marchesa_crystal_drop_earrings/thing?id=225685901
# item4
# item link: http://www.polyvore.com/she_is_anything_but_ordinary/thing?id=198262457
# Item Doesn't Have Category ID!
#
#
# outfit9
# outfit link: https://www.polyvore.com/untitled_1256/set?id=232923485
# item0
# item link: http://www.polyvore.com/caleigh_oversized_knit_cardigan/thing?id=122839806
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(122839806) already exists.
#
# item1
# item link: http://www.polyvore.com/teens_white_nasa_print_shirt/thing?id=208350458
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(208350458) already exists.
#
# item2
# item link: http://www.polyvore.com/pink_ice_destroyed_classics_high/thing?id=187369719
# item3
# item link: http://www.polyvore.com/boohoo_khloe_knee_high_socks/thing?id=152148957
# item4
# item link: http://www.polyvore.com/fjallraven_kanken_water_resistant_backpack/thing?id=227727512
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227727512) already exists.
#
# item5
# item link: http://www.polyvore.com/11pcs_vintage_rose_leaf_carved/thing?id=229172050
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229172050) already exists.
#
# item6
# item link: http://www.polyvore.com/choker/thing?id=229342231
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229342231) already exists.
#
# item7
# item link: http://www.polyvore.com/eugenia_kim_rain_fur_pompom/thing?id=226785389
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226785389) already exists.
#
# item8
# item link: http://www.polyvore.com/purple_iphone_cover/thing?id=230137840
# item9
# item link: http://www.polyvore.com/olive_timberland_boots_mens_inch/thing?id=229624988
# Item Not In Category Women's Fashion!
#
#
# outfit10
# outfit link: https://www.polyvore.com/men_are_dogs/set?id=232924530
# item0
# item link: http://www.polyvore.com/yohji_yamamoto_blazer/thing?id=156484806
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(156484806) already exists.
#
# item1
# item link: http://www.polyvore.com/ace_jig_paperbag-waist_wide-leg_cotton/thing?id=179669420
# item2
# item link: http://www.polyvore.com/womens_steve_madden_insomnia_platform/thing?id=227950898
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227950898) already exists.
#
# item3
# item link: http://www.polyvore.com/pre-owned_twisted_rope_chain_brass/thing?id=146632181
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(146632181) already exists.
#
# item4
# item link: http://www.polyvore.com/round_resin_earrings/thing?id=146087012
# item5
# item link: http://www.polyvore.com/angel_plate_mini_shoulder_bag/thing?id=84838851
#
#
# outfit11
# outfit link: https://www.polyvore.com/untitled_262/set?id=232908681
# item0
# item link: http://www.polyvore.com/halpern_longsleeved_high_neck_sequinned/thing?id=229027412
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229027412) already exists.
#
# item1
# item link: http://www.polyvore.com/mcq_alexander_mcqueen_black_oversized/thing?id=226852800
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226852800) already exists.
#
# item2
# item link: http://www.polyvore.com/blade_pump/thing?id=227550202
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227550202) already exists.
#
# item3
# item link: http://www.polyvore.com/proenza_schouler_metallic_new_linosa/thing?id=224843815
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224843815) already exists.
#
# item4
# item link: http://www.polyvore.com/black_doris/thing?id=216829457
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216829457) already exists.
#
# item5
# item link: http://www.polyvore.com/dior_golden_glow_loose_powder/thing?id=225728741
# Item Not In Category Women's Fashion!
#
#
# outfit12
# outfit link: https://www.polyvore.com/power_look/set?id=232920427
# item0
# item link: http://www.polyvore.com/roberto_cavalli_tailored_crepe_blazer/thing?id=125107602
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(125107602) already exists.
#
# item1
# item link: http://www.polyvore.com/roberto_cavalli_printed_crepe_pants/thing?id=125109437
# item2
# item link: http://www.polyvore.com/satin_convertible_strapless_bra/thing?id=192704633
# item3
# item link: http://www.polyvore.com/power_look_text/thing?id=186482503
# Item Doesn't Have Category ID!
#
#
# outfit13
# outfit link: https://www.polyvore.com/shine/set?id=232921818
# item0
# item link: http://www.polyvore.com/lace_beads_sandy_hazel_iridescent/thing?id=225434393
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225434393) already exists.
#
# item1
# item link: http://www.polyvore.com/kat_black_ripped_skinny_jean/thing?id=229256934
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229256934) already exists.
#
# item2
# item link: http://www.polyvore.com/1352/thing?id=228220452
# item3
# item link: http://www.polyvore.com/jessica_carlyle_st1747g695_gold-tone_black/thing?id=228526609
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228526609) already exists.
#
# item4
# item link: http://www.polyvore.com/audacious_lipstick/thing?id=229307699
# Item Not In Category Women's Fashion!
#
#
# outfit14
# outfit link: https://www.polyvore.com/royal_winter_outfit/set?id=232916304
# item0
# item link: http://www.polyvore.com/prada_point-collar_single-breasted_wool_coat/thing?id=218555755
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218555755) already exists.
#
# item1
# item link: http://www.polyvore.com/stuart_weitzman_tieland_suede_over-the-knee/thing?id=227703458
# item2
# item link: http://www.polyvore.com/bertoni_1949_women_bertoncina_velvet/thing?id=210529575
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(210529575) already exists.
#
# item3
# item link: http://www.polyvore.com/pre-owned_14k_white_gold_briolette/thing?id=228053883
# item4
# item link: http://www.polyvore.com/dudney_powder_coating/thing?id=154734131
# Item Doesn't Have Category ID!
#
#
# outfit15
# outfit link: https://www.polyvore.com/polypresents_new_years_resolutions/set?id=232919180
# item0
# item link: http://www.polyvore.com/nike_top/thing?id=226850711
# item1
# item link: http://www.polyvore.com/nike_indy_mesh-trimmed_dri-fit_stretch-jersey/thing?id=212605498
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(212605498) already exists.
#
# item2
# item link: http://www.polyvore.com/nike_power_legendary_mesh-paneled_dri-fit/thing?id=207182762
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(207182762) already exists.
#
# item3
# item link: http://www.polyvore.com/nike_womens_free_run_flyknit/thing?id=217876102
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(217876102) already exists.
#
# item4
# item link: http://www.polyvore.com/studio_cockatoo_black_cat_a1/thing?id=199598116
# Item Not In Category Women's Fashion!
#
#
# outfit16
# outfit link: https://www.polyvore.com/sem_t%C3%ADtulo_5313/set?id=232907784
# item0
# item link: http://www.polyvore.com/boohoo_petite_jessica_wrap_front/thing?id=224797190
# item1
# item link: http://www.polyvore.com/la_perla_soft_cup_lace/thing?id=221602739
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221602739) already exists.
#
# item2
# item link: http://www.polyvore.com/leopard_pointed_ballet_flat/thing?id=184265520
# item3
# item link: http://www.polyvore.com/saint_laurent_large_sunset_bag/thing?id=225666343
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225666343) already exists.
#
# item4
# item link: http://www.polyvore.com/limited_edition_grunge_bracelet_ring/thing?id=172778253
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(172778253) already exists.
#
#
#
# outfit17
# outfit link: https://www.polyvore.com/sem_t%C3%ADtulo_5315/set?id=232908340
# item0
# item link: http://www.polyvore.com/dresses_alice_olivia/thing?id=212916426
# item1
# item link: http://www.polyvore.com/eberjey_delirious_triangle_bralet/thing?id=45700892
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(45700892) already exists.
#
# item2
# item link: http://www.polyvore.com/suede_pointed_toe_ballet_flat/thing?id=206753615
# item3
# item link: http://www.polyvore.com/tan_vintage_chanel_small_crossbody/thing?id=209748680
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(209748680) already exists.
#
# item4
# item link: http://www.polyvore.com/moon_pendant_chain_necklace_rings/thing?id=220457141
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220457141) already exists.
#
#
#
# outfit18
# outfit link: https://www.polyvore.com/jenna_dewan_tatum_inspired_outfit/set?id=232920476
# item0
# item link: http://www.polyvore.com/galvan_london_neck_camisole_black/thing?id=225208006
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225208006) already exists.
#
# item1
# item link: http://www.polyvore.com/self-portrait/thing?id=230187287
# item2
# item link: http://www.polyvore.com/self-portrait_lace_peplum_skirt/thing?id=141803745
# item3
# item link: http://www.polyvore.com/circle_disc_necklace/thing?id=229118355
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229118355) already exists.
#
# item4
# item link: http://www.polyvore.com/marc_jacobs_le_lip_cr%C3%A8me/thing?id=128533876
# Item Not In Category Women's Fashion!
#
#
# outfit19
# outfit link: https://www.polyvore.com/enchanting/set?id=232921239
# item0
# item link: http://www.polyvore.com/choies_black_sheer_mesh_tie/thing?id=214683191
# item1
# item link: http://www.polyvore.com/calico_embroidery_lace_up_block/thing?id=213072048
# item2
# item link: http://www.polyvore.com/two_rows_unique_flower_rose/thing?id=67431592
# item3
# item link: http://www.polyvore.com/stacked_rhinestone_rings_set_brass/thing?id=13276507
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(13276507) already exists.
#
# item4
# item link: http://www.polyvore.com/natalie_jewelry_moonstone_pendant_double/thing?id=209203966
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(209203966) already exists.
#
# item5
# item link: http://www.polyvore.com/disney_aristocats_im_lady_cord/thing?id=213078065
# item6
# item link: http://www.polyvore.com/omorovicza_limited_edition_queen_hungary/thing?id=220611038
# Item Not In Category Women's Fashion!
#
#
# outfit20
# outfit link: https://www.polyvore.com/vchannel_bee_joonyoung_baby_its/set?id=232909579
# item0
# item link: http://www.polyvore.com/awaveawake_three_tie_blouse/thing?id=225981821
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225981821) already exists.
#
# item1
# item link: http://www.polyvore.com/junya_watanabe_comme_des_gar%C3%A7ons/thing?id=221714882
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221714882) already exists.
#
# item2
# item link: http://www.polyvore.com/gianvito_rossi_marie_lace-up_velvet/thing?id=221513572
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221513572) already exists.
#
# item3
# item link: http://www.polyvore.com/glitter_christmas_tree_stud_earrings/thing?id=228525843
# item4
# item link: http://www.polyvore.com/crystaluxe_holly_pendant_with_red/thing?id=229418978
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229418978) already exists.
#
# item5
# item link: http://www.polyvore.com/amazon.com_vintage_elegant_jewelry_925/thing?id=228768749
# item6
# item link: http://www.polyvore.com/park_bo_young_staggering_increase/thing?id=230256850
# Item Doesn't Have Category ID!
#
#
# outfit21
# outfit link: https://www.polyvore.com/personal_selection/set?id=232923743
# item0
# item link: http://www.polyvore.com/roksanda_reine_tri-colour_pleated_satin/thing?id=189703547
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(189703547) already exists.
#
# item1
# item link: http://www.polyvore.com/topshop_velvet_pleat_midi_skirt/thing?id=186276236
# item2
# item link: http://www.polyvore.com/prada_feather-trimmed_satin_sandals/thing?id=220277303
# item3
# item link: http://www.polyvore.com/charlotte_olympia_vinyl_clutch/thing?id=124289645
# item4
# item link: http://www.polyvore.com/vivien_sheriff_feather_trilby_hat/thing?id=226731152
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226731152) already exists.
#
# item5
# item link: http://www.polyvore.com/lily_pond_peekaboo_sunglasses/thing?id=154108906
# item6
# item link: http://www.polyvore.com/polaroid_snap_touch_instant_print/thing?id=229893052
# Item Doesn't Have Category ID!
#
#
# outfit22
# outfit link: https://www.polyvore.com/untitled_2114/set?id=232908220
# item0
# item link: http://www.polyvore.com/shirts_sweat_nyc_online_store/thing?id=179028867
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(179028867) already exists.
#
# item1
# item link: http://www.polyvore.com/hope_krissy_trouser_shiny_black/thing?id=228931064
# item2
# item link: http://www.polyvore.com/old_skool_black/thing?id=190280646
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(190280646) already exists.
#
# item3
# item link: http://www.polyvore.com/marni_trunk_leather_shoulder_bag/thing?id=216084547
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216084547) already exists.
#
# item4
# item link: http://www.polyvore.com/large_hair_claw/thing?id=47739993
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(47739993) already exists.
#
#
#
# outfit23
# outfit link: https://www.polyvore.com/untitled/set?id=232910757
# item0
# item link: http://www.polyvore.com/ulla_johnson_amina_wool-blend_turtleneck/thing?id=220226955
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220226955) already exists.
#
# item1
# item link: http://www.polyvore.com/solace_london_nora_high-rise_wide-leg/thing?id=226483437
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226483437) already exists.
#
# item2
# item link: http://www.polyvore.com/marc_jacobs_crawford_ankle_boots/thing?id=221703967
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221703967) already exists.
#
# item3
# item link: http://www.polyvore.com/gucci_gg_marmont_small_matelass%C3%A9/thing?id=186591814
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(186591814) already exists.
#
# item4
# item link: http://www.polyvore.com/modern_disk_stack_ring/thing?id=224613227
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224613227) already exists.
#
# item5
# item link: http://www.polyvore.com/abstract_faces_earrings/thing?id=228560405
# item6
# item link: http://www.polyvore.com/vanessa_mooney_heart_locket_necklace/thing?id=228326270
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228326270) already exists.
#
# item7
# item link: http://www.polyvore.com/gucci_aviator_metal_glasses_with/thing?id=221890244
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221890244) already exists.
#
# item8
# item link: http://www.polyvore.com/sea_shell/thing?id=219960729
# Item Not In Category Women's Fashion!
#
#
# outfit24
# outfit link: https://www.polyvore.com/you_just_pull_up_you/set?id=232919347
# item0
# item link: http://www.polyvore.com/patched_pocket_half_zip_hoodie/thing?id=229628505
# item1
# item link: http://www.polyvore.com/melly_joggers_blue/thing?id=207565354
# item2
# item link: http://www.polyvore.com/mcm_stark_studs_medium_backpack/thing?id=165900783
# item3
# item link: http://www.polyvore.com/pre-owned_rolex_datejust_two_tone/thing?id=184840303
# item4
# item link: http://www.polyvore.com/22_rope_chain_slider_necklace/thing?id=211310011
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(211310011) already exists.
#
# item5
# item link: http://www.polyvore.com/native_union_clic_air_iphone/thing?id=165047288
# Item Not In Category Women's Fashion!
#
#
# outfit25
# outfit link: https://www.polyvore.com/love_this_color/set?id=232918368
# item0
# item link: http://www.polyvore.com/peter_pilotto_short_dress/thing?id=210890392
# item1
# item link: http://www.polyvore.com/beige_37_women_shoes_buckle/thing?id=229823752
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229823752) already exists.
#
# item2
# item link: http://www.polyvore.com/sam_edelman_womens_leather_mini/thing?id=226287824
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226287824) already exists.
#
# item3
# item link: http://www.polyvore.com/monica_vinader_nura_rose_gold/thing?id=229684038
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229684038) already exists.
#
#
#
# outfit26
# outfit link: https://www.polyvore.com/polypresents_new_years_resolutions/set?id=232910769
# item0
# item link: http://www.polyvore.com/black_lurex_stripe_ruffle_bardot/thing?id=228380322
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228380322) already exists.
#
# item1
# item link: http://www.polyvore.com/fuchsia_slinky_palazzo_trousers/thing?id=225678251
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225678251) already exists.
#
# item2
# item link: http://www.polyvore.com/nasty_gal_love_fool_vegan/thing?id=220144733
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220144733) already exists.
#
# item3
# item link: http://www.polyvore.com/new_autumn_lichee_grain_pompon/thing?id=226394608
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226394608) already exists.
#
#
#
# outfit27
# outfit link: https://www.polyvore.com/untitled_146/set?id=232909288
# item0
# item link: http://www.polyvore.com/valentino_cropped_virgin_wool_cashmere/thing?id=182358825
# item1
# item link: http://www.polyvore.com/olivier_theyskens_high-rise_straight-leg_jeans/thing?id=213077442
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(213077442) already exists.
#
# item2
# item link: http://www.polyvore.com/60s_lennon_style_sunglasses_red/thing?id=58864440
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(58864440) already exists.
#
# item3
# item link: http://www.polyvore.com/chanel_iman_for_block_summer/thing?id=20036386
# Item Doesn't Have Category ID!
#
#
# outfit28
# outfit link: https://www.polyvore.com/sin_t%C3%ADtulo_2491/set?id=232916540
# item0
# item link: http://www.polyvore.com/versace_ribbed_roll_neck_jumper/thing?id=172819368
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(172819368) already exists.
#
# item1
# item link: http://www.polyvore.com/stella_mccartney_cropped_high-rise_wide-leg/thing?id=174619994
# item2
# item link: http://www.polyvore.com/black_patent_flat_loafers_38/thing?id=119378050
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(119378050) already exists.
#
# item3
# item link: http://www.polyvore.com/frame_denim_ring_belt/thing?id=184684990
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(184684990) already exists.
#
# item4
# item link: http://www.polyvore.com/strandv%C3%A4ska_jute_199/thing?id=206248697
# Item Doesn't Have Category ID!
#
#
# outfit29
# outfit link: https://www.polyvore.com/sin_t%C3%ADtulo_2495/set?id=232918282
# item0
# item link: http://www.polyvore.com/roberto_collina_jumper/thing?id=227152527
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227152527) already exists.
#
# item1
# item link: http://www.polyvore.com/black_leather_flats_christophe_lemaire/thing?id=130630835
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(130630835) already exists.
#
# item2
# item link: http://www.polyvore.com/womens_bony_levy_14k_gold/thing?id=151583486
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(151583486) already exists.
#
# item3
# item link: http://www.polyvore.com/kinto_iced_tea_glass/thing?id=105483767
# Item Not In Category Women's Fashion!
#
#
# outfit30
# outfit link: https://www.polyvore.com/untitled_1640/set?id=232910338
# item0
# item link: http://www.polyvore.com/boohoo_grace_fluffy_sherpa_knitted/thing?id=226771159
# item1
# item link: http://www.polyvore.com/slim_tee/thing?id=229835335
# item2
# item link: http://www.polyvore.com/paige_denim_verdugo_suede_skinny/thing?id=215076108
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(215076108) already exists.
#
# item3
# item link: http://www.polyvore.com/velvet_ankle_boot_tommy_hilfiger/thing?id=229659954
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229659954) already exists.
#
# item4
# item link: http://www.polyvore.com/womens_rebecca_minkoff_medium_keith/thing?id=220422493
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220422493) already exists.
#
# item5
# item link: http://www.polyvore.com/sriking_bronze_pearls_crystals_statement/thing?id=193953827
# item6
# item link: http://www.polyvore.com/dolce_gabbana_belt/thing?id=227574632
#
#
# outfit31
# outfit link: https://www.polyvore.com/mystery/set?id=232915058
# item0
# item link: http://www.polyvore.com/white_one_size_layered_sleeve/thing?id=226773027
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226773027) already exists.
#
# item1
# item link: http://www.polyvore.com/redvalentino_wide-leg_high-rise_crepe_trousers/thing?id=217842022
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(217842022) already exists.
#
# item2
# item link: http://www.polyvore.com/self-portrait_robert_clergerie_velvet_karlit/thing?id=223490918
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223490918) already exists.
#
# item3
# item link: http://www.polyvore.com/mini_flap_closure_handbag_khaki/thing?id=209883307
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(209883307) already exists.
#
# item4
# item link: http://www.polyvore.com/sole_society_le_gala_velvet/thing?id=219578179
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219578179) already exists.
#
# item5
# item link: http://www.polyvore.com/miss_modular_fine_art_print/thing?id=227304505
# Item Not In Category Women's Fashion!
#
#
# outfit32
# outfit link: https://www.polyvore.com/golden_queen/set?id=232923419
# item0
# item link: http://www.polyvore.com/ulla_johnson_giles_ruffled_velvet/thing?id=222449070
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222449070) already exists.
#
# item1
# item link: http://www.polyvore.com/skirt/thing?id=228818182
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228818182) already exists.
#
# item2
# item link: http://www.polyvore.com/womens_manolo_blahnik_isola_brocade/thing?id=219170387
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219170387) already exists.
#
# item3
# item link: http://www.polyvore.com/tory_burch_gemini_link_patent/thing?id=218195348
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218195348) already exists.
#
# item4
# item link: http://www.polyvore.com/dolce_gabbana_heart_earrings/thing?id=223671645
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223671645) already exists.
#
# item5
# item link: http://www.polyvore.com/pre-owned_cartier_rivoli_tinted_sunglasses/thing?id=225688003
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225688003) already exists.
#
# item6
# item link: http://www.polyvore.com/mac_jade_jagger_mineralize_eye/thing?id=229236743
# Item Not In Category Women's Fashion!
#
#
# outfit33
# outfit link: https://www.polyvore.com/romwe_contest_35_for_winner/set?id=232925291
# item0
# item link: http://www.polyvore.com/double_breasted_sherpa_lined_jacket/thing?id=226306239
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226306239) already exists.
#
# item1
# item link: http://www.polyvore.com/back_curve_hem_shorts/thing?id=229501444
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229501444) already exists.
#
# item2
# item link: http://www.polyvore.com/faux_leather_drawstring_flap_backpack/thing?id=228735105
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228735105) already exists.
#
# item3
# item link: http://www.polyvore.com/christmas_wreaths_best_door_decorations/thing?id=227878111
# Item Doesn't Have Category ID!
#
#
# outfit34
# outfit link: https://www.polyvore.com/untitled_4165/set?id=232920352
# item0
# item link: http://www.polyvore.com/proenza_schouler_ribbed_wool_cashmere-blend/thing?id=140539702
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(140539702) already exists.
#
# item1
# item link: http://www.polyvore.com/diane_von_furstenberg_jenna_coat/thing?id=186010959
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(186010959) already exists.
#
# item2
# item link: http://www.polyvore.com/maison_margiela_pleated_wool_tapered/thing?id=218690572
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218690572) already exists.
#
# item3
# item link: http://www.polyvore.com/alexachung_point-toe_patent-leather_ankle_boots/thing?id=211786127
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(211786127) already exists.
#
# item4
# item link: http://www.polyvore.com/luana_italy_mini_satchel_bag/thing?id=220985807
# item5
# item link: http://www.polyvore.com/emilio_pucci_printed_silk_scarf/thing?id=191631513
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(191631513) already exists.
#
# item6
# item link: http://www.polyvore.com/pasotti_women_tropical_fish_umbrella/thing?id=211749223
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(211749223) already exists.
#
#
#
# outfit35
# outfit link: https://www.polyvore.com/sin_titulo/set?id=232920047
# item0
# item link: http://www.polyvore.com/didk_shirt_cute_pink_with/thing?id=208268087
# item1
# item link: http://www.polyvore.com/topshop_casual_bomber_jacket/thing?id=171424235
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(171424235) already exists.
#
# item2
# item link: http://www.polyvore.com/dr_denim_rinsed_blue_plenty/thing?id=52163039
# item3
# item link: http://www.polyvore.com/womens_vans_sf_slip-on_sneaker/thing?id=204406520
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(204406520) already exists.
#
# item4
# item link: http://www.polyvore.com/25_beach_blonde_hair_ideas/thing?id=217285167
# Item Not In Category Women's Fashion!
#
#
# outfit36
# outfit link: https://www.polyvore.com/elena_inspired_outfit_vampire_diaries/set?id=232910685
# item0
# item link: http://www.polyvore.com/velvet_draped_cardigan/thing?id=221602947
# item1
# item link: http://www.polyvore.com/temperley_london_canterbury_jumper/thing?id=70047569
# item2
# item link: http://www.polyvore.com/skinny_high_ankle_jeans_14.99/thing?id=202222564
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(202222564) already exists.
#
# item3
# item link: http://www.polyvore.com/sole_society_austen_faux_shearling/thing?id=222399860
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222399860) already exists.
#
#
#
# outfit37
# outfit link: https://www.polyvore.com/209/set?id=232923078
# item0
# item link: http://www.polyvore.com/evie_plunge_front_halterneck_bodycon/thing?id=227676392
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227676392) already exists.
#
# item1
# item link: http://www.polyvore.com/bke_extra_long_lean_tank/thing?id=218580746
# item2
# item link: http://www.polyvore.com/shein_sheinside_faux_fur_trim/thing?id=226935477
# item3
# item link: http://www.polyvore.com/giuseppe_zanotti_design_high-tops_sneakers/thing?id=228104641
# item4
# item link: http://www.polyvore.com/pink_polly_pocket_heart_shaped/thing?id=228026166
# item5
# item link: http://www.polyvore.com/peal_cable_knit_gloves/thing?id=229877107
# item6
# item link: http://www.polyvore.com/north_face_womens_shinsky_beanie/thing?id=229292173
# item7
# item link: http://www.polyvore.com/pre-owned_viktor_rolf_silk_striped/thing?id=221075437
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221075437) already exists.
#
# item8
# item link: http://www.polyvore.com/keep_it_full_nourishing_lip/thing?id=230159607
# Item Not In Category Women's Fashion!
#
#
# outfit38
# outfit link: https://www.polyvore.com/idk/set?id=232914653
# item0
# item link: http://www.polyvore.com/new_look_black_pink_floyd/thing?id=169945998
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(169945998) already exists.
#
# item1
# item link: http://www.polyvore.com/destructed_skinny_jeans/thing?id=95248824
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(95248824) already exists.
#
# item2
# item link: http://www.polyvore.com/converse_chuck_taylor_all_star/thing?id=209627384
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(209627384) already exists.
#
# item3
# item link: http://www.polyvore.com/unisex_shinsky_beanie/thing?id=221980554
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221980554) already exists.
#
# item4
# item link: http://www.polyvore.com/47_hot_long_bob_haircuts/thing?id=159334087
# Item Doesn't Have Category ID!
#
#
# outfit39
# outfit link: https://www.polyvore.com/gorgeous_jade/set?id=232912976
# item0
# item link: http://www.polyvore.com/boohoo_tia_velvet_draped_tie/thing?id=226230592
# item1
# item link: http://www.polyvore.com/jimmy_choo_krissy_100_crystal/thing?id=225652572
# item2
# item link: http://www.polyvore.com/gedebe_clicky_clutch/thing?id=225088717
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225088717) already exists.
#
# item3
# item link: http://www.polyvore.com/malaika_firth_naj_jamai_for/thing?id=137644253
# Item Doesn't Have Category ID!
#
#
# outfit40
# outfit link: https://www.polyvore.com/away_from_my_goal/set?id=232916406
# item0
# item link: http://www.polyvore.com/pink/thing?id=170510545
# item1
# item link: http://www.polyvore.com/abercrombie_fitch_high_rise_super/thing?id=89234057
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(89234057) already exists.
#
# item2
# item link: http://www.polyvore.com/converse_womens_white_chuck_taylor/thing?id=201985524
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(201985524) already exists.
#
# item3
# item link: http://www.polyvore.com/livre_iv_iphone_case_cover/thing?id=205093502
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(205093502) already exists.
#
# item4
# item link: http://www.polyvore.com/tarte_rainforest_sea_eyeshadow_palette/thing?id=163530513
# Item Not In Category Women's Fashion!
#
#
# outfit41
# outfit link: https://www.polyvore.com/untitled_1259/set?id=232914360
# item0
# item link: http://www.polyvore.com/pre-owned_opening_ceremony_green_cropped/thing?id=188941834
# item1
# item link: http://www.polyvore.com/allsaints_hawley_oversized_shearling_biker/thing?id=220301216
# item2
# item link: http://www.polyvore.com/saint_laurent_high_waist_skinny/thing?id=136203168
# item3
# item link: http://www.polyvore.com/saint_laurent_blake_40_jodhpur/thing?id=158592454
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(158592454) already exists.
#
# item4
# item link: http://www.polyvore.com/gucci_gg_marmont_matelass%C3%A9_mini/thing?id=206539560
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(206539560) already exists.
#
# item5
# item link: http://www.polyvore.com/arca_classic_havana_sunglasses/thing?id=206754137
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(206754137) already exists.
#
# item6
# item link: http://www.polyvore.com/vintage_m%C3%A5ne/thing?id=118925092
# Item Doesn't Have Category ID!
#
#
# outfit42
# outfit link: https://www.polyvore.com/sem_t%C3%ADtulo_294/set?id=232918603
# item0
# item link: http://www.polyvore.com/ann_demeulemeester_asymmetric_trapper_jumper/thing?id=219907770
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219907770) already exists.
#
# item1
# item link: http://www.polyvore.com/rhythm_fun4alls_overalls_shop_beginning/thing?id=90191155
# item2
# item link: http://www.polyvore.com/monsoon_sheer_floral_lace_trim/thing?id=163497561
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(163497561) already exists.
#
# item3
# item link: http://www.polyvore.com/puma_basket_patent_sneakers/thing?id=219176768
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219176768) already exists.
#
# item4
# item link: http://www.polyvore.com/moschino_recycled_bear_crossbody_bag/thing?id=216101545
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216101545) already exists.
#
# item5
# item link: http://www.polyvore.com/ashlynd_womens_bunny_iphone_case/thing?id=218962082
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218962082) already exists.
#
# item6
# item link: http://www.polyvore.com/house_home_artificial_rose_bouquet/thing?id=219238198
# Item Not In Category Women's Fashion!
#
#
# outfit43
# outfit link: https://www.polyvore.com/favorite_pants/set?id=232922441
# item0
# item link: http://www.polyvore.com/miss_selfridge_cobalt_angel_sleeve/thing?id=226875615
# item1
# item link: http://www.polyvore.com/dolce_gabbana_printed_cotton-poplin_culottes/thing?id=219268747
# item2
# item link: http://www.polyvore.com/manolo_blahnik_womens_rapalla_satin/thing?id=229169004
# item3
# item link: http://www.polyvore.com/givenchy_infinity_saddle_leather_shoulder/thing?id=219110761
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219110761) already exists.
#
#
#
# outfit44
# outfit link: https://www.polyvore.com/untitled_4758/set?id=232909146
# item0
# item link: http://www.polyvore.com/phillip_lim_lace_slip_cami/thing?id=196349041
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(196349041) already exists.
#
# item1
# item link: http://www.polyvore.com/allsaints_vettese_studded_leather_biker/thing?id=178336488
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(178336488) already exists.
#
# item2
# item link: http://www.polyvore.com/3x1_w3_higher_ground_cropped/thing?id=213075844
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(213075844) already exists.
#
# item3
# item link: http://www.polyvore.com/stars_embroidered_ankle_boots/thing?id=222642992
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222642992) already exists.
#
# item4
# item link: http://www.polyvore.com/alexander_mcqueen_heroine_21_mini/thing?id=229952222
# item5
# item link: http://www.polyvore.com/cut-out_brushed_ring_set/thing?id=173211459
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(173211459) already exists.
#
#
#
# outfit45
# outfit link: https://www.polyvore.com/tommy_hilfiger/set?id=232908581
# item0
# item link: http://www.polyvore.com/tommy_jeans_flag_print_longsleeved/thing?id=223784782
# item1
# item link: http://www.polyvore.com/tommy_hilfiger_coat/thing?id=229915288
# item2
# item link: http://www.polyvore.com/tommy_hilfiger_gigi_hadid_destroyed/thing?id=221033519
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221033519) already exists.
#
# item3
# item link: http://www.polyvore.com/velvet_ankle_boot_tommy_hilfiger/thing?id=229659954
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229659954) already exists.
#
# item4
# item link: http://www.polyvore.com/tommy_hilfiger_wallet/thing?id=226614423
# item5
# item link: http://www.polyvore.com/tommy_hilfiger_ellie_gold_tone/thing?id=200554287
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(200554287) already exists.
#
# item6
# item link: http://www.polyvore.com/tommy_hilfiger_girl_eau_de/thing?id=227863268
# Item Not In Category Women's Fashion!
#
#
# outfit46
# outfit link: https://www.polyvore.com/rihanna/set?id=232910083
# item0
# item link: http://www.polyvore.com/hellessy_hutton_wrap_waist_shirt/thing?id=220683895
# item1
# item link: http://www.polyvore.com/christian_louboutin_yellow_so_kate/thing?id=230052752
# item2
# item link: http://www.polyvore.com/jacquemus_le_sac_chiquito/thing?id=222493401
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222493401) already exists.
#
# item3
# item link: http://www.polyvore.com/jennifer_fisher_womens_classic_hollow/thing?id=227194414
# item4
# item link: http://www.polyvore.com/rose_gold_pearl_diamond_starburst/thing?id=230117548
# item5
# item link: http://www.polyvore.com/rihanna_official_street_naming_ceremony/thing?id=230258341
# Item Doesn't Have Category ID!
#
#
# outfit47
# outfit link: https://www.polyvore.com/untitled_1590/set?id=232913960
# item0
# item link: http://www.polyvore.com/philosophy_di_lorenzo_serafini_black/thing?id=226953349
# item1
# item link: http://www.polyvore.com/miu_crystal-embellished_satin_sandals/thing?id=219803176
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219803176) already exists.
#
# item2
# item link: http://www.polyvore.com/dolce_gabbana_black_box_bag/thing?id=228979999
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228979999) already exists.
#
# item3
# item link: http://www.polyvore.com/swarovski_crystaldust_wrap_bracelet/thing?id=180661999
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(180661999) already exists.
#
# item4
# ...
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224393263) already exists.
#
# item5
# item link: http://www.polyvore.com/mother_madonna_starburst_necklace/thing?id=224393342
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224393342) already exists.
#
# item6
# item link: http://www.polyvore.com/liat_hoop_earrings/thing?id=226745572
# item7
# item link: http://www.polyvore.com/cartier_d%C3%A9cor_optical_glasses/thing?id=195221775
# item8
# item link: http://www.polyvore.com/stiletto_nails/thing?id=161493325
# Item Not In Category Women's Fashion!
#
#
# outfit116
# outfit link: https://www.polyvore.com/untitled_2361/set?id=232912471
# item0
# item link: http://www.polyvore.com/womens_short_sleeve_casual_loose/thing?id=217527779
# item1
# item link: http://www.polyvore.com/lace_up_block_heeled_ankle/thing?id=224283567
# item2
# item link: http://www.polyvore.com/tommy_hilfiger_backpacks_bum_bags/thing?id=226856913
# item3
# item link: http://www.polyvore.com/burberry_long_chunky_knit_striped/thing?id=226952275
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226952275) already exists.
#
#
#
# outfit117
# outfit link: https://www.polyvore.com/thanks_guys_so_much_for/set?id=232918312
# item0
# item link: http://www.polyvore.com/hoodies_sweatshirts_pink/thing?id=189403423
# item1
# item link: http://www.polyvore.com/victoria_distressed_boyfriend_jeans/thing?id=227068637
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227068637) already exists.
#
# item2
# item link: http://www.polyvore.com/vera_bradley_lilac_paisley_iconic/thing?id=225215651
# item3
# item link: http://www.polyvore.com/chocolate_gold_eyeshadow_palette_too/thing?id=226636539
# Item Not In Category Women's Fashion!
#
#
# outfit118
# outfit link: https://www.polyvore.com/park_chanyeol/set?id=232908863
# item0
# item link: http://www.polyvore.com/wine_red_lapel_long_sleeve/thing?id=223751441
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223751441) already exists.
#
# item1
# item link: http://www.polyvore.com/romwe_womens_knot_front_cuffed/thing?id=225809799
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225809799) already exists.
#
# item2
# item link: http://www.polyvore.com/vice_jeans_skinny_fit_black/thing?id=222589788
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222589788) already exists.
#
# item3
# item link: http://www.polyvore.com/lace_up_high_heeled_ankle/thing?id=220587968
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220587968) already exists.
#
# item4
# item link: http://www.polyvore.com/winona_drawstring_backpack_black/thing?id=208228533
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(208228533) already exists.
#
# item5
# item link: http://www.polyvore.com/black_heart_earrings_jewelry_minimal/thing?id=190411702
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(190411702) already exists.
#
# item6
# item link: http://www.polyvore.com/kate_spade_jazz_things_up/thing?id=180368604
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(180368604) already exists.
#
# item7
# item link: http://www.polyvore.com/embroidered_slogan_baseball_cap/thing?id=227354542
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227354542) already exists.
#
# item8
# item link: http://www.polyvore.com/unisex_back_black_elastic_suspenders/thing?id=164439283
# item9
# item link: http://www.polyvore.com/nars_back_room_nail_polish/thing?id=125472156
# Item Not In Category Women's Fashion!
#
#
# outfit119
# outfit link: https://www.polyvore.com/maddox_brooke/set?id=232924540
# item0
# item link: http://www.polyvore.com/black_lurex_stripe_ruffle_bardot/thing?id=228380322
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228380322) already exists.
#
# item1
# item link: http://www.polyvore.com/arise_to_top_high_waist/thing?id=154011184
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(154011184) already exists.
#
# item2
# item link: http://www.polyvore.com/vans_slip-on/thing?id=185364358
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(185364358) already exists.
#
# item3
# item link: http://www.polyvore.com/tatti_lashes/thing?id=228390573
# Item Not In Category Women's Fashion!
#
#
# outfit120
# outfit link: https://www.polyvore.com/polypresents_new_years_resolutions/set?id=232908411
# item0
# item link: http://www.polyvore.com/boohoo_fiona_plunge_ruffle_crop/thing?id=228773581
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228773581) already exists.
#
# item1
# item link: http://www.polyvore.com/neeson_womens_basic_versatile_stretchy/thing?id=228410962
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228410962) already exists.
#
# item2
# item link: http://www.polyvore.com/sophia_webster_shoes_black_velvet/thing?id=221883649
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221883649) already exists.
#
# item3
# item link: http://www.polyvore.com/kerry_velvet_pearl_cross_body/thing?id=225516572
# item4
# item link: http://www.polyvore.com/red_herring_layered_tassel_drop/thing?id=228109486
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228109486) already exists.
#
# item5
# item link: http://www.polyvore.com/choker/thing?id=229342231
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229342231) already exists.
#
# item6
# item link: http://www.polyvore.com/fashion_case_w16_iphone_port/thing?id=228487244
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228487244) already exists.
#
# item7
# item link: http://www.polyvore.com/audacious_lipstick/thing?id=229307699
# Item Not In Category Women's Fashion!
#
#
# outfit121
# outfit link: https://www.polyvore.com/love_glitters/set?id=232914666
# item0
# item link: http://www.polyvore.com/ashish_neck_sequin-embellished_mini_dress/thing?id=222642882
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222642882) already exists.
#
# item1
# item link: http://www.polyvore.com/dolce_gabbana_velvet_crystal-embellished_satin/thing?id=226795240
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226795240) already exists.
#
# item2
# item link: http://www.polyvore.com/glittery_shoulder_bag_12.99/thing?id=229015860
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229015860) already exists.
#
# item3
# item link: http://www.polyvore.com/le_vian_crazy_multi-stone_14k/thing?id=225205536
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225205536) already exists.
#
# item4
# item link: http://www.polyvore.com/futuro_remoto_gioielli_women_dragonfly/thing?id=229861895
# item5
# item link: http://www.polyvore.com/korres_wild_rose_vitamin_active/thing?id=226792788
# Item Not In Category Women's Fashion!
#
#
# outfit122
# outfit link: https://www.polyvore.com/metallic_accents_for_winter/set?id=232917076
# item0
# item link: http://www.polyvore.com/brochu_walker_pale_purple_pullover/thing?id=217043484
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(217043484) already exists.
#
# item1
# item link: http://www.polyvore.com/lands_end_womens_petite_wool/thing?id=182452402
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(182452402) already exists.
#
# item2
# item link: http://www.polyvore.com/for_all_mankind_mid-rise_bootcut/thing?id=123961753
# item3
# item link: http://www.polyvore.com/status_leather_ruffle_loafers/thing?id=229661422
# item4
# item link: http://www.polyvore.com/womens_michael_michael_kors_medium/thing?id=127407372
# item5
# item link: http://www.polyvore.com/pre-owned_chanel_necklace_sautoir_pearls/thing?id=99602194
# item6
# item link: http://www.polyvore.com/carolee_manhattan_medley_two_tone/thing?id=111641469
# item7
# item link: http://www.polyvore.com/peach_lightweight_scarf_with_bold/thing?id=169878534
# item8
# item link: http://www.polyvore.com/tom_ford_whitney_sunglasses_in/thing?id=38769429
#
#
# outfit123
# outfit link: https://www.polyvore.com/going_to_ball/set?id=232918663
# item0
# item link: http://www.polyvore.com/zimmermann_esplanade_brocade_bodice/thing?id=143135813
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(143135813) already exists.
#
# item1
# item link: http://www.polyvore.com/gareth_pugh_embroidered_silk_cotton/thing?id=85676789
# item2
# item link: http://www.polyvore.com/imagine_vince_camuto_womens_devin/thing?id=212992927
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(212992927) already exists.
#
# item3
# item link: http://www.polyvore.com/louis_vuitton_louise_clutch_leather/thing?id=213150312
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(213150312) already exists.
#
# item4
# item link: http://www.polyvore.com/aur%C3%A9lie_bidermann_aphrodite_gold-plated_tree/thing?id=44080999
# item5
# item link: http://www.polyvore.com/we_heart_it/thing?id=10382044
# Item Doesn't Have Category ID!
#
#
# outfit124
# outfit link: https://www.polyvore.com/shein/set?id=232914764
# item0
# item link: http://www.polyvore.com/shein_sheinside_rib_knit_fluted/thing?id=223507027
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223507027) already exists.
#
# item1
# item link: http://www.polyvore.com/shein_sheinside_houndstooth_fringe_trim/thing?id=230147969
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(230147969) already exists.
#
# item2
# item link: http://www.polyvore.com/river_island_white_harper_high/thing?id=227728919
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227728919) already exists.
#
# item3
# item link: http://www.polyvore.com/laureen_heels/thing?id=229053401
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229053401) already exists.
#
# item4
# item link: http://www.polyvore.com/tassels_faux_leather_crossbody_bag/thing?id=226389737
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226389737) already exists.
#
# item5
# item link: http://www.polyvore.com/hourglass_ambient_metallic_strobe_lighting/thing?id=220484460
# Item Not In Category Women's Fashion!
#
#
# outfit125
# outfit link: https://www.polyvore.com/through_wardrobe/set?id=232913656
# item0
# item link: http://www.polyvore.com/dolce_gabbana_tweed_crop_top/thing?id=89378646
# item1
# item link: http://www.polyvore.com/monsoon_berry_lindsey_velvet_coat/thing?id=39346577
# item2
# item link: http://www.polyvore.com/yumi_check_print_skater_skirt/thing?id=151429160
# item3
# item link: http://www.polyvore.com/converse_black_athletic_shoes/thing?id=152659043
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(152659043) already exists.
#
# item4
# item link: http://www.polyvore.com/olive_brass_fingerless_military_gloves/thing?id=24540695
# item5
# item link: http://www.polyvore.com/snow_photography_minimal_winter_landscape/thing?id=71066651
# Item Doesn't Have Category ID!
#
#
# outfit126
# outfit link: https://www.polyvore.com/polypresents_new_years_resolutions/set?id=232924227
# item0
# item link: http://www.polyvore.com/solid_color_off-the-shoulder_split-side_maxi/thing?id=230153903
# item1
# item link: http://www.polyvore.com/giuseppe_zanotti_sophie/thing?id=213073046
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(213073046) already exists.
#
# item2
# item link: http://www.polyvore.com/true_decadence_rounded_box_clutch/thing?id=227856260
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227856260) already exists.
#
# item3
# item link: http://www.polyvore.com/silver_one-size_retro_metal_rings/thing?id=229366080
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229366080) already exists.
#
# item4
# item link: http://www.polyvore.com/120mm_silver-tone_skinny_hoop_earrings/thing?id=228502769
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228502769) already exists.
#
# item5
# item link: http://www.polyvore.com/lemonade_glitter_eye_shadow_in/thing?id=226545934
# Item Not In Category Women's Fashion!
#
#
# outfit127
# outfit link: https://www.polyvore.com/rose/set?id=232917287
# item0
# item link: http://www.polyvore.com/off_shoulder_single_breasted_blouse/thing?id=212708104
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(212708104) already exists.
#
# item1
# item link: http://www.polyvore.com/shein_sheinside_long_sleeve_mohair/thing?id=229432196
# item2
# item link: http://www.polyvore.com/womens_ag_legging_super_skinny/thing?id=227546937
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227546937) already exists.
#
# item3
# item link: http://www.polyvore.com/white_pink_pu_rubber_sole/thing?id=225526822
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225526822) already exists.
#
# item4
# item link: http://www.polyvore.com/saint_laurent_women_bellechasse_leather/thing?id=218174840
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218174840) already exists.
#
# item5
# item link: http://www.polyvore.com/lele_sadoughi_crystal_lily_ring/thing?id=211371732
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(211371732) already exists.
#
# item6
# item link: http://www.polyvore.com/cherry_cupcake_pink_cute_with/thing?id=207657131
# item7
# item link: http://www.polyvore.com/cgi/thing?id=221982153
# Item Doesn't Have Category ID!
#
#
# outfit128
# outfit link: https://www.polyvore.com/sin_t%C3%ADtulo_246/set?id=232914323
# item0
# item link: http://www.polyvore.com/markus_lupfer_metallic_foil_savannah/thing?id=157858273
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(157858273) already exists.
#
# item1
# item link: http://www.polyvore.com/florence_bridge_matilda_mongolian_lambswool/thing?id=221913978
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221913978) already exists.
#
# item2
# item link: http://www.polyvore.com/pre-owned_pumps_turquoise/thing?id=214991342
# item3
# item link: http://www.polyvore.com/chiara_cross-body_bag/thing?id=228429762
# item4
# item link: http://www.polyvore.com/beaded_necklace_rope_lime_green/thing?id=229629252
# item5
# item link: http://www.polyvore.com/yeprem_wild_flames_earrings/thing?id=202026340
# item6
# item link: http://www.polyvore.com/white_gold_pear_shape_round/thing?id=228704944
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228704944) already exists.
#
# item7
# item link: http://www.polyvore.com/apres_ski_glow_face_palette/thing?id=226883064
# Item Not In Category Women's Fashion!
#
#
# END!
