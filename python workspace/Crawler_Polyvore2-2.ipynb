# %% [markdown]
# # Polyvore Crawler for Storing to DB

# %%
# %matplotlib inline
import matplotlib
from matplotlib import pyplot as plt
import os
import time
import cv2
import json
import requests
from requests.exceptions import *
import psycopg2
import shutil
from PIL import Image
from lxml import html
from bs4 import BeautifulSoup
from datetime import date, datetime
import numpy as np
from numpy import *
from pylab import *
import pandas
from pandas import Series, DataFrame
import multiprocessing

# %%
# Connect to postgres database
conn = psycopg2.connect(database="fashion", user="michellechen", password="", host="127.0.0.1", port="5432")

print "Opened database successfully"

# Connection cursor to database
cur = conn.cursor()

# Create outfit table
cur.execute('''CREATE TABLE IF NOT EXISTS outfits(
                outfit_id INT PRIMARY KEY NOT NULL,
                link TEXT NOT NULL,
                title TEXT,
                image TEXT,
                author TEXT,
                create_date TEXT,
                views INT,
                likes INT,
                description TEXT,
                similar1 TEXT,
                similar2 TEXT,
                similar3 TEXT,
                similar4 TEXT,
                similar5 TEXT
                )''')

# Create outfit_item table
cur.execute('''CREATE TABLE IF NOT EXISTS outfit_item(
                id TEXT PRIMARY KEY NOT NULL,
                outfit_id INT,
                item_id INT
                )''')

# Create outfit item table
cur.execute('''CREATE TABLE IF NOT EXISTS items(
                item_id INT PRIMARY KEY NOT NULL,
                link TEXT NOT NULL,
                title TEXT,
                image TEXT,
                category1_id INT,
                category1_name TEXT,
                category2_id INT,
                category2_name TEXT,
                category3_id INT,
                category3_name TEXT,
                category4_id INT,
                category4_name TEXT,
                brand TEXT,
                price TEXT,
                likes INT,
                description TEXT,
                keyword1 TEXT,
                keyword2 TEXT,
                keyword3 TEXT,
                keyword4 TEXT,
                keyword5 TEXT,
                keyword6 TEXT
                )''')

conn.commit() 

print "Table created successfully"
# Out:
# Opened database successfully
# Table created successfully

# %%
# Headers
head = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'}

# %%
# Crawl item data with item link
def crawl_item(day, outfit_id, line):
    
    # Initialize
    item_id = 0
    item_link = ""
    item_title = ""
    item_image = ""
    item_category_id = [0, 0, 0, 0]
    item_category_name = ["", "", "", ""]
    item_brand = ""
    item_price = ""
    item_likes = 0
    item_description = ""
    item_keywords = ["", "", "", "", "", ""]
    
    # Item id
    item_id = int(line.split('\n')[0].split('=')[-1])
    #print "item id: " + str(item_id)

    # Item link
    item_link = line.split('context_id')[0] + "id=" + str(item_id)
    print "item link: " + item_link
    
    # Get request response
    while True:
        try:
            res = requests.get(item_link, headers = head)
        except RequestException:
            print "Item Request Connection Error!"
            print "Delay 1 minutes!"
            time.sleep(60) # Delay 60 seconds
        else:
            break
    
    # If Item page is not found
    if res.status_code == 404:
        print "HTTP Response Error " + str(res.status_code)
        print "Item Not Found!"
        return 0
    
    # When http response error
    while res.status_code != 200:
        print "HTTP Response Error " + str(res.status_code)
        time.sleep(3) # Delay 3 seconds
        res = requests.get(item_link, headers = head)
        if res.status_code == 200:
            break

    # Parse html with BeautifulSoup
    soup = BeautifulSoup(res.text, "html.parser")
    
    # Item category
    try:
        category = int(soup.select('.crumb')[0].select('a')[0]['href'].split('=')[-1])
    except ValueError: # Not in category
        print "Item Doesn't Have Category ID!"
        return 0
    else:
        if category != 1: # Not in category "Women's Fashion" 
            print "Item Not In Category Women's Fashion!"
            return 0
        else:
            for index, item in enumerate(soup.select('.crumb')):
                try:
                    item_category_id[index] = int(item.select('a')[0]['href'].split('=')[-1])
                    #print str(item_category_id[index])
                except ValueError:
                    pass
                
                item_category_name[index] = item.select('a')[0].select('span')[0].text       
                #print item_category_name[index]

                # Item brand
                if 'brand=' in item.select('a')[0]['href']:
                    item_brand = item.select('a')[0]['href'].split('brand=')[-1].split('&')[0]
                    #print "item brand: " + item_brand
                    
            # Item title
            item_title = soup.find_all('meta', {'property': 'og:title'})[0]['content']
            #print "item title: " + item_title

            # Item image
            item_image = soup.find_all('meta', {'property': 'og:image'})[0]['content']
            #print "item image: " + item_image
            
            # Save Item image as a jpg file
            while True:
                try: 
                    image_res = requests.get(item_image, stream = True)
                except ConnectionError:
                    print "Image Request Connection Error!"
                    time.sleep(3) # Delay 3 seconds
                else:
                    break
                
            f = open('item_images/' + day + '/' + day + '-' + str(outfit_id) + '-'+ str(item_id) + '.jpg', 'wb')
            shutil.copyfileobj(image_res.raw, f)
            f.close

            # Item price
            try: 
                item_price = soup.select('div.bd')[0].select('.price')[0].text
                #print "item price: " + item_price 
            except IndexError:
                try:
                    item_price = soup.select('div.bd')[0].select('.orig_price')[0].text
                    #print "item price: " + item_price 
                except IndexError:
                    pass
           
            # Item likes
            item_likes = int(soup.find_all('meta', {'property': 'polyvore:saves'})[0]['content'])
            #print "item likes: " + str(item_likes)

            # Item description
            try:
                item_description = soup.select('.tease')[0].text
                #print "item description: " + item_description
            except IndexError:
                pass

            # Item keyword 
            try:
                soup.select('#related_searches')[0].select('a')
            except IndexError:
                pass
            else:
                for index, keyword in enumerate(soup.select('#related_searches')[0].select('a')):
                    if index >= 6:
                        break
                    item_keywords[index] = keyword.text
            #print "item keywords: " + item_keywords
            
           
        
            ############################# Insert item data into database ###############################
            
            # Insert item data into items table
            query = '''INSERT INTO items
                        (item_id, link, title, image, category1_id, category1_name, category2_id, category2_name,
                        category3_id, category3_name, category4_id, category4_name, brand, price, likes,
                        description, keyword1, keyword2, keyword3, keyword4, keyword5, keyword6) 
                        VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);'''
            data = (item_id, item_link, item_title, item_image, item_category_id[0], item_category_name[0], 
                    item_category_id[1], item_category_name[1], item_category_id[2], item_category_name[2],
                    item_category_id[3], item_category_name[3], item_brand, item_price, item_likes, item_description, 
                    item_keywords[0], item_keywords[1], item_keywords[2], item_keywords[3], item_keywords[4], 
                    item_keywords[5])

            try:
                cur.execute(query, data)
            except psycopg2.Error, e:
                print "Item pass!"
                print e.pgerror
                pass

            conn.commit()
            
            
            ########################## Insert outfit-item data into database ###########################

            # Insert outfit-item pairing data into outfit-item table
            pairing_query =  '''INSERT INTO outfit_item (id, outfit_id, item_id) 
                                VALUES(%s, %s, %s);'''
            pairing_data = (str(outfit_id) + "-" + str(item_id), outfit_id, item_id)

            try:
                cur.execute(pairing_query, pairing_data)
            except psycopg2.Error, e:
                print "Outfit-Item pass!"
                print e.pgerror
                pass

            conn.commit()
           
    return 1

# %%
# Crawl outfit data with outfit link
def crawl_outfit (day, line):
  
    # Initialize 
    outfit_link = ""
    outfit_id = 0
    outfit_title = ""
    outfit_image = ""
    outfit_author = ""
    outfit_date = ""
    outfit_views = 0
    outfit_likes = 0
    outfit_description = ""
    outfit_similars = []

    # Get request response
    while True:
        try:
            res = requests.get(line, headers = head)
        except RequestException:
            print "Outfit Request Connection Error!"
            print "Delay 1 minutes!"
            time.sleep(60) # Delay 60 seconds
        else:
            break

    # If outfit page is not found
    if res.status_code == 404:
        # Skip to next outfit
        print "HTTP Response Error " + str(res.status_code)
        print "Outfit Not Found!"
        return
    
    # When http response error
    while res.status_code != 200:
        # Print error code
        print "HTTP Response Error " + str(res.status_code)
        # Delay 3 seconds
        time.sleep(3) 
        # Requests again
        res = requests.get(line, headers = head) 
        if res.status_code == 200:
            break

    # Parse html with BeautifulSoup
    soup = BeautifulSoup(res.text, "html.parser")

    # Outfit link
    outfit_link = line.split('\n')[0]
    print "outfit link: " + outfit_link

    # Outfit id
    outfit_id = int(outfit_link.split('/')[-1].split('=')[-1])
    #print "outfit id: " + str(outfit_id)

    # Outfit title
    outfit_title = soup.find_all('meta', {'property': 'og:title'})[0]['content']
    #print "outfit title: " + outfit_title

    # Outfit image
    outfit_image = soup.find_all('meta', {'property': 'og:image'})[0]['content']
    #print "outfit image: " + outfit_image

    # Save outfit image as a jpg file
    while True:
        try: 
            image_res = requests.get(outfit_image, stream = True)
        except ConnectionError:
            print "Image Request Connection Error!"
            time.sleep(3) # Delay 3 seconds
            continue
        break

    f = open('outfit_images/' + day + '/' + day + '-' + str(outfit_id) + '.jpg', 'wb')
    shutil.copyfileobj(image_res.raw, f)
    f.close

    # Outfit author link
    outfit_author = soup.find_all('meta', {'property': 'polyvore:author'})[0]['content']
    #print "outfit author: " + outfit_author

    # Outfit create time
    outfit_date = day
    #print "outfit create: " + outfit_date

    # Outfit views count
    outfit_views = int(str(soup.select('div.meta')[0].select('div')[-1])[5:-7].split('.')[1].split()[0].replace(',', ''))
    #print "outfit views: " + str(outfit_views)

    # Outfit likes count
    outfit_likes = int(soup.find_all('meta', {'property': 'polyvore:likes'})[0]['content'])
    #print "outfit likes: " + str(outfit_likes)

    # Outfit description
    outfit_description = soup.select('div.bd')[0].select('img')[0]['alt']
    #print "outfit description: " + outfit_description

    # Outfit similar style
    for grid in soup.select('.grid_item.hover_container.type_set.span2w.span2h'):
        for main in grid.select('div.main'):
            outfit_similars.append('http://www.polyvore.com/' + main.select('a')[0]['href'][3:])

    # If similar outfits do not have 5 outfits, append empty one
    if len(outfit_similars) != 5:
        for i in xrange(5 - len(outfit_similars)):
            outfit_similars.append("")

#         for i in xrange(len(outfit_similars)):
#             print "outfit similar " + str(i) + ": " + outfit_similars[i]     



    ############################# Insert outfit data into database #############################    

    # Insert outfit data into outfit table
    outfit_query = '''INSERT INTO outfits 
                        (outfit_id, link, title, image, author, create_date, views, likes, 
                        description, similar1, similar2, similar3, similar4, similar5) 
                        VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);'''
    outfit_data = (outfit_id, outfit_link, outfit_title, outfit_image, outfit_author, outfit_date, 
            outfit_views, outfit_likes, outfit_description, 
            outfit_similars[0], outfit_similars[1], outfit_similars[2], outfit_similars[3], outfit_similars[4])

    try:
        cur.execute(outfit_query, outfit_data)
    except psycopg2.Error, e:
        print "Outfit pass!"
        print e.pgerror
        pass

    conn.commit()


    #################################### Items in the outfit ###################################

    # initialize
    item_count = 0
    item_link = []   

    # Outfit set_item grid
    done = False
    for grid in soup.select('.grid_item.hover_container.type_thing.span1w.span1h'):
        for main in grid.select('div.main'): 

            print "item" + str(item_count)

            item_link.append('http://www.polyvore.com/' + main.select('a')[0]['href'][3:])
            #print "item link " + str(item_count) + ": " + item_link[item_count]

            # Crawl item data, if item is not in category, then next item is not too
            if crawl_item(day, outfit_id, item_link[item_count]) == 0:

                # If first item is not in category, the outfit is not a fashion outfit
                if item_count == 0:

                    print "Remove outfit!"
                    # Delete this outfit row in outfit table
                    outfit_delete = '''DELETE FROM outfits 
                                        WHERE outfit_id = ''' + str(outfit_id) + ''';'''
                    cur.execute(outfit_delete)
                    conn.commit()

                    # Remove this outfit image file
                    os.remove('outfit_images/' + day + '/' + day + '-' + str(outfit_id) + '.jpg')

                done = True
                break # Break the inner for loop

            item_count += 1

#         # If done is true, we do not need to run the next item
        if done: 
            break # Break the outer for loop
       
    return

# %%
# Crawler for all outfits and items in one day
def crawler(day):

    # Create new folder with day name for storing outfit images
    if not os.path.exists('outfit_images/' + day):
        os.makedirs('outfit_images/' + day)

    # Create new folder with day name for storing item images
    if not os.path.exists('item_images/' + day):
        os.makedirs('item_images/' + day)
    
    # Initialize
    outfit_count = 0

    # Open the file
    with open('outfit_links/Today_Outfit_Links_'+ day +'.txt', 'r') as f:
        
        # Read every links in this txt file
        for line in f.readlines():
            
            print "outfit" + str(outfit_count)
            
            if outfit_count != 0 and outfit_count % 50 == 0:
                print "Delay 1 minute!"
                time.sleep(60) # Delay 60 seconds

            # Crawl outfit
            crawl_outfit(day, line)

            print "\n"
            outfit_count += 1
            
    return

# %%
day = '20171228'

crawler(day)

# Close the connection to database
cur.close()
conn.close()

print "END!"
# Out:
# outfit0
# outfit link: https://www.polyvore.com/little_sweet_but_not_too/set?id=232822596
# Outfit pass!
# ERROR:  duplicate key value violates unique constraint "outfits_pkey"
# DETAIL:  Key (outfit_id)=(232822596) already exists.
#
# item0
# item link: http://www.polyvore.com/bella_freud_star_intarsia_jumper/thing?id=229685323
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229685323) already exists.
#
# Outfit-Item pass!
# ERROR:  duplicate key value violates unique constraint "outfit_item_pkey"
# DETAIL:  Key (id)=(232822596-229685323) already exists.
#
# item1
# item link: http://www.polyvore.com/sjyp_embellished_oversized_jacket/thing?id=229734094
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229734094) already exists.
#
# Outfit-Item pass!
# ERROR:  duplicate key value violates unique constraint "outfit_item_pkey"
# DETAIL:  Key (id)=(232822596-229734094) already exists.
#
# item2
# item link: http://www.polyvore.com/frame_le_skinny_de_jeanne/thing?id=206077032
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(206077032) already exists.
#
# Outfit-Item pass!
# ERROR:  duplicate key value violates unique constraint "outfit_item_pkey"
# DETAIL:  Key (id)=(232822596-206077032) already exists.
#
# item3
# item link: http://www.polyvore.com/red_valentino_embellished_leather_ankle/thing?id=219035837
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219035837) already exists.
#
# Outfit-Item pass!
# ERROR:  duplicate key value violates unique constraint "outfit_item_pkey"
# DETAIL:  Key (id)=(232822596-219035837) already exists.
#
# item4
# item link: http://www.polyvore.com/rebecca_minkoff_medium_darren_backpack/thing?id=223245893
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223245893) already exists.
#
# Outfit-Item pass!
# ERROR:  duplicate key value violates unique constraint "outfit_item_pkey"
# DETAIL:  Key (id)=(232822596-223245893) already exists.
#
# item5
# item link: http://www.polyvore.com/roberto_cavalli_moon_star_necklace/thing?id=181997163
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(181997163) already exists.
#
# Outfit-Item pass!
# ERROR:  duplicate key value violates unique constraint "outfit_item_pkey"
# DETAIL:  Key (id)=(232822596-181997163) already exists.
#
# item6
# item link: http://www.polyvore.com/drop_shadow/thing?id=36389364
# Item Doesn't Have Category ID!
#
#
# outfit1
# outfit link: https://www.polyvore.com/unbenannt_9033/set?id=232831181
# item0
# item link: http://www.polyvore.com/moschino_trompe_loeil_bow_blouse/thing?id=222944140
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222944140) already exists.
#
# item1
# item link: http://www.polyvore.com/moschino_silver_trimmed_mini_skirt/thing?id=224472309
# item2
# item link: http://www.polyvore.com/moschino_heel/thing?id=218696731
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218696731) already exists.
#
# item3
# item link: http://www.polyvore.com/moschino_new_biker_flap_bag/thing?id=223607410
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223607410) already exists.
#
# item4
# item link: http://www.polyvore.com/karolina_kurkova/thing?id=43517583
# Item Doesn't Have Category ID!
#
#
# outfit2
# outfit link: https://www.polyvore.com/untitled_3544/set?id=232818767
# item0
# item link: http://www.polyvore.com/kai_faux_shearling_biker_jacket/thing?id=222538762
# item1
# item link: http://www.polyvore.com/vilshenko_elayna_floral-print_wide-leg_pleated/thing?id=219804208
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219804208) already exists.
#
# item2
# item link: http://www.polyvore.com/topshop_katz2_cut_out_shoes/thing?id=86920608
# item3
# item link: http://www.polyvore.com/american_apparel_haight_sunglasses/thing?id=76319159
# item4
# item link: http://www.polyvore.com/serapi_collection_rug_83_101/thing?id=89233559
# Item Not In Category Women's Fashion!
#
#
# outfit3
# outfit link: https://www.polyvore.com/set/set?id=232831200
# item0
# item link: http://www.polyvore.com/caelan_crop_top_motel/thing?id=223088728
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223088728) already exists.
#
# item1
# item link: http://www.polyvore.com/alice_grace_pearl_stretch_satin/thing?id=215682505
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(215682505) already exists.
#
# item2
# item link: http://www.polyvore.com/gucci_queen_margaret_leather_pump/thing?id=224495938
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224495938) already exists.
#
# item3
# item link: http://www.polyvore.com/ellia_wang_layer_clutch_in/thing?id=217489134
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(217489134) already exists.
#
# item4
# item link: http://www.polyvore.com/frame/thing?id=12792346
# Item Doesn't Have Category ID!
#
#
# outfit4
# outfit link: https://www.polyvore.com/they_say_good_things_come/set?id=232820451
# item0
# item link: http://www.polyvore.com/velvet_graham_spencer_cali_ruffle-trimmed/thing?id=224531656
# item1
# item link: http://www.polyvore.com/essie_ultra_distressed_jeans/thing?id=210435424
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(210435424) already exists.
#
# item2
# item link: http://www.polyvore.com/dolce_vita_tay_dark_taupe/thing?id=220796298
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220796298) already exists.
#
# item3
# item link: http://www.polyvore.com/tory_burch_britten_zip_leather/thing?id=227079143
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227079143) already exists.
#
# item4
# item link: http://www.polyvore.com/guess_marciano_gold-tone_layered_necklace/thing?id=224058125
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224058125) already exists.
#
# item5
# item link: http://www.polyvore.com/iphone_plus_apple_specs_price/thing?id=224893502
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224893502) already exists.
#
# item6
# item link: http://www.polyvore.com/stila_matte_metal_eye_shadow/thing?id=209323198
# Item Not In Category Women's Fashion!
#
#
# outfit5
# outfit link: https://www.polyvore.com/romwe_drop_shoulder_patch_detail/set?id=232831880
# item0
# item link: http://www.polyvore.com/drop_shoulder_patch_detail_hoodie/thing?id=229488918
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229488918) already exists.
#
# item1
# item link: http://www.polyvore.com/shein_sheinside_black_skinny_elastic/thing?id=159460221
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(159460221) already exists.
#
# item2
# item link: http://www.polyvore.com/nike_air_max_zero_sneakers/thing?id=222459086
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222459086) already exists.
#
# item3
# item link: http://www.polyvore.com/mcm_shoulder_bag_dual_stark/thing?id=215555542
# item4
# item link: http://www.polyvore.com/stuffed_pink_bears_twinkle_bear/thing?id=11366744
# Item Doesn't Have Category ID!
#
#
# outfit6
# outfit link: https://www.polyvore.com/interviewer_for_mtv/set?id=232829520
# item0
# item link: http://www.polyvore.com/ulla_johnson_giles_ruffled_velvet/thing?id=222449070
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222449070) already exists.
#
# item1
# item link: http://www.polyvore.com/abrasion_skinny_jeans/thing?id=221174769
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221174769) already exists.
#
# item2
# item link: http://www.polyvore.com/aldo_edalen_suede_ankle_boots/thing?id=219348421
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219348421) already exists.
#
# item3
# item link: http://www.polyvore.com/iphone_plus_silicone_case_white/thing?id=215732820
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(215732820) already exists.
#
# item4
# item link: http://www.polyvore.com/beth_bender_beauty/thing?id=178332474
# Item Not In Category Women's Fashion!
#
#
# outfit7
# outfit link: https://www.polyvore.com/untitled_1425/set?id=232830520
# item0
# item link: http://www.polyvore.com/alexander_wang_chain_strap_crop/thing?id=227899484
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227899484) already exists.
#
# item1
# item link: http://www.polyvore.com/acne_studios_velocite_leather-trimmed_shearling/thing?id=223093247
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223093247) already exists.
#
# item2
# item link: http://www.polyvore.com/re_done_grunge_destroyed_straight/thing?id=229053028
# item3
# item link: http://www.polyvore.com/off-white_for_walking_ankle_boots/thing?id=229895496
# item4
# item link: http://www.polyvore.com/chanel_vintage_cc_chain_backpack/thing?id=220199601
# item5
# item link: http://www.polyvore.com/get_image_html_code_cool/thing?id=162121933
# Item Doesn't Have Category ID!
#
#
# outfit8
# outfit link: https://www.polyvore.com/eva1809/set?id=232830298
# item0
# item link: http://www.polyvore.com/mango_turtle_neck_oversize_sweater/thing?id=226377801
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226377801) already exists.
#
# item1
# item link: http://www.polyvore.com/red_faux_leather_stud_detail/thing?id=215914311
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(215914311) already exists.
#
# item2
# item link: http://www.polyvore.com/louder/thing?id=228830339
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228830339) already exists.
#
# item3
# item link: http://www.polyvore.com/les_petits_joueurs_baby_alex/thing?id=218375012
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218375012) already exists.
#
# item4
# item link: http://www.polyvore.com/reminiscence_women_hey_jude_earrings/thing?id=223908899
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223908899) already exists.
#
# item5
# item link: http://www.polyvore.com/lulu_in_sky_kiss_comic/thing?id=213112327
# item6
# item link: http://www.polyvore.com/womens_oversized_full_metal_geometric/thing?id=214399980
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(214399980) already exists.
#
#
#
# outfit9
# outfit link: https://www.polyvore.com/yuri_on_ice_inspired/set?id=232831257
# item0
# item link: http://www.polyvore.com/msgm_sequins_embellished_top/thing?id=221601965
# item1
# item link: http://www.polyvore.com/mbj_womens_basic_versatile_stretchy/thing?id=132749852
# item2
# item link: http://www.polyvore.com/elder_statesman_yosemite_socks/thing?id=229193716
# item3
# item link: http://www.polyvore.com/dew_sterling_silver_star_stud/thing?id=228149761
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228149761) already exists.
#
# item4
# item link: http://www.polyvore.com/marble_rebel_heart_quote_iphone/thing?id=216661650
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216661650) already exists.
#
# item5
# item link: http://www.polyvore.com/yves_saint_laurent_couture_variation/thing?id=222685234
# Item Not In Category Women's Fashion!
#
#
# outfit10
# outfit link: https://www.polyvore.com/untitled_410/set?id=232818410
# item0
# item link: http://www.polyvore.com/red_valentino_open_back_short/thing?id=227826422
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227826422) already exists.
#
# item1
# item link: http://www.polyvore.com/miu_crystal-embellished_mohair-blend_coat/thing?id=221235067
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221235067) already exists.
#
# item2
# item link: http://www.polyvore.com/rebecca_taylor_ruffled-cuff_cropped_floral-jacquard/thing?id=226115878
# item3
# item link: http://www.polyvore.com/rebecca_minkoff_womens_gerry_floral/thing?id=222483435
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222483435) already exists.
#
# item4
# item link: http://www.polyvore.com/chopard_happy_hearts_18-karat_rose/thing?id=222942799
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222942799) already exists.
#
# item5
# item link: http://www.polyvore.com/janavi_beaded_cashmere_scarf/thing?id=225948817
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225948817) already exists.
#
#
#
# outfit11
# outfit link: https://www.polyvore.com/untitled_71/set?id=232829167
# item0
# item link: http://www.polyvore.com/balmain_sleeveless_day_dress/thing?id=205507830
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(205507830) already exists.
#
# item1
# item link: http://www.polyvore.com/christian_louboutin_classe_100mm_over-the-knee/thing?id=219757606
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219757606) already exists.
#
# item2
# item link: http://www.polyvore.com/pre-owned_charlotte_olympia_this_is/thing?id=229304421
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229304421) already exists.
#
# item3
# item link: http://www.polyvore.com/miss_selfridge_pink_retro_circle/thing?id=225204870
# item4
# item link: http://www.polyvore.com/drop_shadow/thing?id=36389364
# Item Doesn't Have Category ID!
#
#
# outfit12
# outfit link: https://www.polyvore.com/christmas_day_plaid/set?id=232826302
# item0
# item link: http://www.polyvore.com/red_5xl_plus_size_christmas/thing?id=229893987
# item1
# item link: http://www.polyvore.com/womens_ellie_gogo-fur/thing?id=228075951
# item2
# item link: http://www.polyvore.com/apothic_red_grape_blend_californian/thing?id=226464472
# Item Not In Category Women's Fashion!
#
#
# outfit13
# outfit link: https://www.polyvore.com/untitled_8373/set?id=232832318
# item0
# item link: http://www.polyvore.com/dsquared2_button_down_shirt/thing?id=195996849
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(195996849) already exists.
#
# item1
# item link: http://www.polyvore.com/paige_denim_distressed_callie_boyfriend/thing?id=131370991
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(131370991) already exists.
#
# item2
# item link: http://www.polyvore.com/almond_toe_block_heeled_suede/thing?id=226609256
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226609256) already exists.
#
# item3
# item link: http://www.polyvore.com/saint_laurent_grey_small_monogram/thing?id=215995317
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(215995317) already exists.
#
# item4
# item link: http://www.polyvore.com/nars_dual-intensity_eyeshadow/thing?id=221270313
# Item Not In Category Women's Fashion!
#
#
# outfit14
# outfit link: https://www.polyvore.com/untitled_8375/set?id=232832415
# item0
# item link: http://www.polyvore.com/new_look_go_pu_skater/thing?id=224261256
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224261256) already exists.
#
# item1
# item link: http://www.polyvore.com/alexander_wang_lou_metallic_slide/thing?id=212591665
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(212591665) already exists.
#
# item2
# item link: http://www.polyvore.com/augen_fake_lashes_mascara_von/thing?id=214926052
# Item Not In Category Women's Fashion!
#
#
# outfit15
# outfit link: https://www.polyvore.com/untitled_8372/set?id=232832280
# item0
# item link: http://www.polyvore.com/fairview_jumpsuit/thing?id=216289028
# item1
# item link: http://www.polyvore.com/christian_louboutin_patent_so_kate/thing?id=155255036
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(155255036) already exists.
#
# item2
# item link: http://www.polyvore.com/saint_laurent_womens_monogram_kate/thing?id=178443738
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(178443738) already exists.
#
# item3
# item link: http://www.polyvore.com/caravelle_womens_crystal_pave_stainless/thing?id=225482895
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225482895) already exists.
#
# item4
# item link: http://www.polyvore.com/thomas_sabo_glam_soul_black/thing?id=218620876
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218620876) already exists.
#
# item5
# item link: http://www.polyvore.com/edited_chanel_nailpolish_ana/thing?id=13187159
# Item Not In Category Women's Fashion!
#
#
# outfit16
# outfit link: https://www.polyvore.com/wear_what_you_want_to/set?id=232818915
# item0
# item link: http://www.polyvore.com/topshop_petite_floral_embroidered_pinafore/thing?id=214979629
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(214979629) already exists.
#
# item1
# item link: http://www.polyvore.com/wearall_long_sleeve_turtleneck_ribbed/thing?id=176458561
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(176458561) already exists.
#
# item2
# item link: http://www.polyvore.com/silver_starry_net_large_mesh/thing?id=217596850
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(217596850) already exists.
#
# item3
# item link: http://www.polyvore.com/row_leather-trimmed_round-frame_acetate_metal/thing?id=110749526
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(110749526) already exists.
#
# item4
# item link: http://www.polyvore.com/gucci_flora_gorgeous_gardenia_50ml/thing?id=180365899
# Item Not In Category Women's Fashion!
#
#
# outfit17
# outfit link: https://www.polyvore.com/untitled_8370/set?id=232832227
# item0
# item link: http://www.polyvore.com/narciso_rodriguez_silk_gown/thing?id=188824824
# item1
# item link: http://www.polyvore.com/pre-owned_dolce_gabbana_leather_heels/thing?id=213619437
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(213619437) already exists.
#
# item2
# item link: http://www.polyvore.com/jimmy_choo_celeste_crystal-embellished_suede/thing?id=212349207
# item3
# item link: http://www.polyvore.com/miadora_10k_white_gold_created/thing?id=117007056
# item4
# item link: http://www.polyvore.com/allurez_ladies_ruby_diamond_halo/thing?id=110204495
# item5
# item link: http://www.polyvore.com/lancome_matte_shaker_high_pigment/thing?id=218826197
# Item Not In Category Women's Fashion!
#
#
# outfit18
# outfit link: https://www.polyvore.com/untitled_4316/set?id=232831475
# item0
# item link: http://www.polyvore.com/philipp_plein_complete_me_dress/thing?id=226282394
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226282394) already exists.
#
# item1
# item link: http://www.polyvore.com/embroidered_relaxed_jeans/thing?id=213876042
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(213876042) already exists.
#
# item2
# item link: http://www.polyvore.com/betsey_johnson_womens_diem_floral/thing?id=227382485
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227382485) already exists.
#
# item3
# item link: http://www.polyvore.com/rebecca_minkoff_velvet_leo_clutch/thing?id=227188587
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227188587) already exists.
#
# item4
# item link: http://www.polyvore.com/colours_christmas_mistletoe/thing?id=98977404
# Item Doesn't Have Category ID!
#
#
# outfit19
# outfit link: https://www.polyvore.com/polypresents_new_years_resolutions/set?id=232832307
# item0
# item link: http://www.polyvore.com/adidas_stella_mccartney_cropped_tee/thing?id=216774649
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216774649) already exists.
#
# item1
# item link: http://www.polyvore.com/black_olivia_stretch_jersey_sports/thing?id=225222554
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225222554) already exists.
#
# item2
# item link: http://www.polyvore.com/adidas_design_move_training_shorts/thing?id=229089914
# item3
# item link: http://www.polyvore.com/adidas_nmd_r1_primeknit_sneakers/thing?id=218492717
# item4
# item link: http://www.polyvore.com/marc_jacobs_double_cutout_ponytail/thing?id=226790104
# item5
# item link: http://www.polyvore.com/apple_watch_series_gps_42mm/thing?id=225286675
# Item Doesn't Have Category ID!
#
#
# outfit20
# outfit link: https://www.polyvore.com/geek/set?id=232832265
# item0
# item link: http://www.polyvore.com/teens_white_nasa_print_shirt/thing?id=208350458
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(208350458) already exists.
#
# item1
# item link: http://www.polyvore.com/garbo_faux_fur_coat/thing?id=229027635
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229027635) already exists.
#
# item2
# item link: http://www.polyvore.com/saint_laurent_asymmetric_leather_skirt/thing?id=201380487
# item3
# item link: http://www.polyvore.com/snake_crew_socks/thing?id=228193349
# item4
# item link: http://www.polyvore.com/victoria_beckham_pin_leather_pumps/thing?id=219656744
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219656744) already exists.
#
# item5
# item link: http://www.polyvore.com/chanel_electric_blue_patent_large/thing?id=157453522
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(157453522) already exists.
#
# item6
# item link: http://www.polyvore.com/niza_huang_jewellery_under_earth/thing?id=227028113
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227028113) already exists.
#
# item7
# item link: http://www.polyvore.com/anita_ko_multi_point_ring/thing?id=101315212
# item8
# item link: http://www.polyvore.com/saint_laurent_ruthenium-plated_crystal_enamel/thing?id=216207458
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216207458) already exists.
#
# item9
# item link: http://www.polyvore.com/ray-ban_round_frame_sunglasses/thing?id=219260284
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219260284) already exists.
#
# item10
# item link: http://www.polyvore.com/lime_crime_polly_velvetine_liquid/thing?id=219452755
# Item Not In Category Women's Fashion!
#
#
# outfit21
# outfit link: https://www.polyvore.com/unbenannt_9037/set?id=232831360
# item0
# item link: http://www.polyvore.com/miu_belted_knitted_jumper/thing?id=222237322
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222237322) already exists.
#
# item1
# item link: http://www.polyvore.com/miu_printed_vinyl_trench_coat/thing?id=228715378
# item2
# item link: http://www.polyvore.com/miu_circle_striped-print_wool-blend_trousers/thing?id=204093746
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(204093746) already exists.
#
# item3
# item link: http://www.polyvore.com/miu_womens_colorblocked_patent_leather/thing?id=223686552
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223686552) already exists.
#
# item4
# item link: http://www.polyvore.com/pre-owned_miu_shoulder/thing?id=219352069
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219352069) already exists.
#
# item5
# item link: http://www.polyvore.com/miu_silver_large_rhinestone_pearl/thing?id=229757611
# item6
# item link: http://www.polyvore.com/karolina_kurkova/thing?id=43517583
# Item Doesn't Have Category ID!
#
#
# outfit22
# outfit link: https://www.polyvore.com/platforms/set?id=232826678
# item0
# item link: http://www.polyvore.com/off_shoulder_tie_front_top/thing?id=228858355
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228858355) already exists.
#
# item1
# item link: http://www.polyvore.com/sea_wide-leg_cotton_cropped_trousers/thing?id=214887751
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(214887751) already exists.
#
# item2
# item link: http://www.polyvore.com/aquazzura_sundance_striped_leather_platform/thing?id=226134640
# item3
# item link: http://www.polyvore.com/aquazzura_striped_leather_sundance_140/thing?id=225260390
# item4
# item link: http://www.polyvore.com/kate_spade_new_york_striped/thing?id=227076758
# item5
# item link: http://www.polyvore.com/le_vieux_silver-plated_onyx_marcasite/thing?id=219452235
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219452235) already exists.
#
# item6
# item link: http://www.polyvore.com/dannijo_black_vix_velvet_choker/thing?id=228419703
# item7
# item link: http://www.polyvore.com/element_joie_beret_black/thing?id=228341816
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228341816) already exists.
#
# item8
# item link: http://www.polyvore.com/ray-ban_rb3532_50_grey_null/thing?id=213620168
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(213620168) already exists.
#
# item9
# item link: http://www.polyvore.com/audacious_lipstick/thing?id=229307699
# Item Not In Category Women's Fashion!
#
#
# outfit23
# outfit link: https://www.polyvore.com/lavender/set?id=232815277
# item0
# item link: http://www.polyvore.com/redvalentino_short_dress/thing?id=223186164
# item1
# item link: http://www.polyvore.com/christian_louboutin_feerica_crystal-flower_embellished/thing?id=219264528
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219264528) already exists.
#
# item2
# item link: http://www.polyvore.com/pink_faux_leather_backpack_with/thing?id=227355803
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227355803) already exists.
#
# item3
# item link: http://www.polyvore.com/carolee_bryant_park_openwork_frontal/thing?id=169336252
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(169336252) already exists.
#
# item4
# item link: http://www.polyvore.com/preowned_victorian_50_carat_natural/thing?id=216297824
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216297824) already exists.
#
# item5
# item link: http://www.polyvore.com/luxiro_rose_gold_finish_sterling/thing?id=190174399
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(190174399) already exists.
#
# item6
# item link: http://www.polyvore.com/jewelled_dusk_purple_eyes_set/thing?id=206655612
# Item Not In Category Women's Fashion!
#
#
# outfit24
# outfit link: https://www.polyvore.com/do_it_with_style/set?id=232828716
# item0
# item link: http://www.polyvore.com/preowned_john_galliano_2010_wine/thing?id=211626116
# item1
# item link: http://www.polyvore.com/dolce_gabbana_women_105mm_keira/thing?id=226395054
# item2
# item link: http://www.polyvore.com/franchi_taylor_rosette_box_clutch/thing?id=45873509
# item3
# item link: http://www.polyvore.com/pre-owned_chanel_earrings/thing?id=204950137
# item4
# item link: http://www.polyvore.com/ginette_ny_mini_monogram_18-karat_rose/thing?id=147730154
# item5
# item link: http://www.polyvore.com/red_flower_iphone_case_plus/thing?id=212177806
# item6
# item link: http://www.polyvore.com/lor%C3%A9al_drops_beauty_beast_inspired/thing?id=200979871
# Item Not In Category Women's Fashion!
#
#
# outfit25
# outfit link: https://www.polyvore.com/untitled_1163/set?id=232829700
# item0
# item link: http://www.polyvore.com/womens_topshop_satin_trim_overlay/thing?id=126603831
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(126603831) already exists.
#
# item1
# item link: http://www.polyvore.com/miss_selfridge_grey_waterfall_duster/thing?id=170432900
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(170432900) already exists.
#
# item2
# item link: http://www.polyvore.com/gianvito_rossi_metallic_leather_plexi/thing?id=112267639
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(112267639) already exists.
#
# item3
# item link: http://www.polyvore.com/jill_haber_christopher_mirrored_clutch/thing?id=226480212
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226480212) already exists.
#
# item4
# item link: http://www.polyvore.com/heidi_daus_snowflake_crystal_pin/thing?id=228099986
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228099986) already exists.
#
#
#
# outfit26
# outfit link: https://www.polyvore.com/polypresents_new_years_resolutions/set?id=232829946
# item0
# item link: http://www.polyvore.com/adidas_stella_mccartney_grey_yoga/thing?id=219341476
# item1
# item link: http://www.polyvore.com/express_marled_exp_core_lace-up/thing?id=219151802
# item2
# item link: http://www.polyvore.com/adidas_edge_lux_womens_running/thing?id=230019087
# item3
# item link: http://www.polyvore.com/eluxury_600_gsm_piece_long/thing?id=221590902
# Item Not In Category Women's Fashion!
#
#
# outfit27
# outfit link: https://www.polyvore.com/unbenannt_9034/set?id=232831230
# item0
# item link: http://www.polyvore.com/dolce_gabbana_lace_slip_dress/thing?id=220969725
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220969725) already exists.
#
# item1
# item link: http://www.polyvore.com/dolce_gabbana_floral-print_leather_pumps/thing?id=213494095
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(213494095) already exists.
#
# item2
# item link: http://www.polyvore.com/dolce_gabbana_millennials_embellished_metallic/thing?id=228484357
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228484357) already exists.
#
# item3
# item link: http://www.polyvore.com/dolce_gabbana_heart_earrings/thing?id=223671645
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223671645) already exists.
#
# item4
# item link: http://www.polyvore.com/karolina_kurkova/thing?id=43517583
# Item Doesn't Have Category ID!
#
#
# outfit28
# outfit link: https://www.polyvore.com/cinderella/set?id=232829553
# item0
# item link: http://www.polyvore.com/gucci_chantilly_lace_gown/thing?id=230017573
# item1
# item link: http://www.polyvore.com/giuseppe_zanotti_mistico_crystal-embellished_metallic/thing?id=228187886
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228187886) already exists.
#
# item2
# item link: http://www.polyvore.com/giuseppe_zanotti_mistico_crystal-embellished_metallic/thing?id=228185141
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228185141) already exists.
#
# item3
# item link: http://www.polyvore.com/delpozo_mo_exclusive_mini_metallic/thing?id=228182271
# item4
# item link: http://www.polyvore.com/ewa_18ct_white_gold_diamond/thing?id=221031297
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221031297) already exists.
#
#
#
# outfit29
# outfit link: https://www.polyvore.com/xxx/set?id=232832485
# item0
# item link: http://www.polyvore.com/fenty_rihanna_wool_minidress/thing?id=226208099
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226208099) already exists.
#
# item1
# item link: http://www.polyvore.com/womens_lapel_long_sleeve_casual/thing?id=223525562
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223525562) already exists.
#
# item2
# item link: http://www.polyvore.com/christian_louboutin_hot_jeanbi_stiletto/thing?id=227375032
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227375032) already exists.
#
# item3
# item link: http://www.polyvore.com/striped_birds_embellished_rhinestone_crossbody/thing?id=226393722
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226393722) already exists.
#
# item4
# item link: http://www.polyvore.com/kate_spade_new_york_confetti/thing?id=225776692
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225776692) already exists.
#
#
#
# outfit30
# outfit link: https://www.polyvore.com/ss18_dlrboutique/set?id=232827071
# item0
# item link: http://www.polyvore.com/alex_perry_elizabeth_black_silk/thing?id=221410477
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221410477) already exists.
#
# item1
# item link: http://www.polyvore.com/jimmy_choo_glitter_romy_100/thing?id=229140024
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229140024) already exists.
#
# item2
# item link: http://www.polyvore.com/jimmy_choo_florence_clutch_bag/thing?id=229228982
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229228982) already exists.
#
# item3
# item link: http://www.polyvore.com/woman_crush_wednesday_taylor_hill/thing?id=225322647
# Item Doesn't Have Category ID!
#
#
# outfit31
# outfit link: https://www.polyvore.com/untitled_8361/set?id=232831749
# item0
# item link: http://www.polyvore.com/miss_selfridge_blush_drape_playsuit/thing?id=212650409
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(212650409) already exists.
#
# item1
# item link: http://www.polyvore.com/gianvito_rossi_women_100mm_plexi/thing?id=190844037
# item2
# item link: http://www.polyvore.com/womens_chloe_drew_leather_shoulder/thing?id=132873620
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(132873620) already exists.
#
# item3
# item link: http://www.polyvore.com/linda_stone_statement_drop_earrings/thing?id=227858654
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227858654) already exists.
#
# item4
# item link: http://www.polyvore.com/bobbi_brown_bellini_mini_lip/thing?id=149839830
# Item Not In Category Women's Fashion!
#
#
# outfit32
# outfit link: https://www.polyvore.com/unbenannt_9032/set?id=232831116
# item0
# item link: http://www.polyvore.com/emporio_armani_jumper/thing?id=229128419
# item1
# item link: http://www.polyvore.com/emporio_armani_poppy_skirt/thing?id=159515948
# item2
# item link: http://www.polyvore.com/emporio_armani_sandals/thing?id=227169516
# item3
# item link: http://www.polyvore.com/pre-owned_emporio_armani_ponyhair_leather/thing?id=208802034
# item4
# item link: http://www.polyvore.com/emporio_armani_earrings/thing?id=224203243
# item5
# item link: http://www.polyvore.com/karolina_kurkova/thing?id=43517583
# Item Doesn't Have Category ID!
#
#
# outfit33
# outfit link: https://www.polyvore.com/6761/set?id=232829102
# item0
# item link: http://www.polyvore.com/boohoo_joy_sleeve_tailored_dress/thing?id=226195246
# item1
# item link: http://www.polyvore.com/preowned_90s_adrienne_landau_black/thing?id=221887022
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221887022) already exists.
#
# item2
# item link: http://www.polyvore.com/iro_bootev_boot/thing?id=222220689
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222220689) already exists.
#
# item3
# item link: http://www.polyvore.com/michael_kors_collection_bancroft_large/thing?id=228898241
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228898241) already exists.
#
# item4
# item link: http://www.polyvore.com/chelsea_black_gold/thing?id=229048139
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229048139) already exists.
#
# item5
# item link: http://www.polyvore.com/amazing_summer_cocktail_recipes/thing?id=170887623
# Item Doesn't Have Category ID!
#
#
# outfit34
# outfit link: https://www.polyvore.com/polypresents_new_year_resolutions/set?id=232829123
# item0
# item link: http://www.polyvore.com/seven_spark_adult_unisex_heavyweight/thing?id=230124998
# item1
# item link: http://www.polyvore.com/misbhv_photo_patch_puffer_jacket/thing?id=227657958
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227657958) already exists.
#
# item2
# item link: http://www.polyvore.com/hollister_low-rise_boyfriend_jeans/thing?id=224511868
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224511868) already exists.
#
# item3
# item link: http://www.polyvore.com/ugg_milla_shearling_ankle_boots/thing?id=226606131
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226606131) already exists.
#
# item4
# item link: http://www.polyvore.com/seven_spark_cotton_tote_bag/thing?id=230125331
# item5
# item link: http://www.polyvore.com/wordscrub_pom_knit_cap/thing?id=223616902
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223616902) already exists.
#
# item6
# item link: http://www.polyvore.com/quote_slim_phone_cases/thing?id=228978763
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228978763) already exists.
#
# item7
# item link: http://www.polyvore.com/bobbi_brown_lip_liner/thing?id=228264821
# Item Not In Category Women's Fashion!
#
#
# outfit35
# outfit link: https://www.polyvore.com/6768/set?id=232829651
# item0
# item link: http://www.polyvore.com/boohoo_larsa_suede_choker_dress/thing?id=229767267
# item1
# item link: http://www.polyvore.com/zizzi_black_plus_size_faux/thing?id=224250718
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224250718) already exists.
#
# item2
# item link: http://www.polyvore.com/balenciaga_ceinture_ankle_boots/thing?id=229160098
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229160098) already exists.
#
# item3
# item link: http://www.polyvore.com/burberry_zip_buckle_leather_crossbody/thing?id=229956716
# item4
# item link: http://www.polyvore.com/gold_simple_chain_bracelet/thing?id=228538429
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228538429) already exists.
#
# item5
# item link: http://www.polyvore.com/new_cocktails_to_share_with/thing?id=155017596
# Item Doesn't Have Category ID!
#
#
# outfit36
# outfit link: https://www.polyvore.com/bright_outerwear/set?id=232827397
# item0
# item link: http://www.polyvore.com/balmain_high-neck_ribbed-knit_wool_dress/thing?id=219771232
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219771232) already exists.
#
# item1
# item link: http://www.polyvore.com/lapels_faux_fur_coat/thing?id=228176461
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228176461) already exists.
#
# item2
# item link: http://www.polyvore.com/marc_jacobs_leather_knee_boots/thing?id=223592615
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223592615) already exists.
#
# item3
# item link: http://www.polyvore.com/midi_hoops/thing?id=228190399
# item4
# item link: http://www.polyvore.com/black_cat_eye_reflective_lenses/thing?id=180272369
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(180272369) already exists.
#
# item5
# item link: http://www.polyvore.com/moschino_80s_gold_chain_adjustable/thing?id=228771125
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228771125) already exists.
#
# item6
# item link: http://www.polyvore.com/vaneau_gm/thing?id=211334472
# Item Doesn't Have Category ID!
#
#
# outfit37
# outfit link: https://www.polyvore.com/sin_t%C3%ADtulo_2456/set?id=232827273
# item0
# item link: http://www.polyvore.com/nili_lotan_frayed_hem_cropped/thing?id=206780505
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(206780505) already exists.
#
# item1
# item link: http://www.polyvore.com/leather_flats_topshop/thing?id=203326389
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(203326389) already exists.
#
# item2
# item link: http://www.polyvore.com/cath_kidston_daisy_pearl_pendant/thing?id=89482490
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(89482490) already exists.
#
# item3
# item link: http://www.polyvore.com/alexanderetere_khov/thing?id=46403562
# item4
# item link: http://www.polyvore.com/gold_notes_things_we_carry/thing?id=53248426
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(53248426) already exists.
#
# item5
# item link: http://www.polyvore.com/cigarette/thing?id=8543275
# Item Doesn't Have Category ID!
#
#
# outfit38
# outfit link: https://www.polyvore.com/6767/set?id=232829608
# item0
# item link: http://www.polyvore.com/boohoo_tammy_oriental_crochet_waist/thing?id=229764658
# item1
# item link: http://www.polyvore.com/womens_steve_madden_insomnia_platform/thing?id=227950898
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227950898) already exists.
#
# item2
# item link: http://www.polyvore.com/prada_mini_saffiano_leather_double-zip/thing?id=186161358
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(186161358) already exists.
#
# item3
# item link: http://www.polyvore.com/abs_allen_schwartz_stone_bangle/thing?id=229242187
# item4
# item link: http://www.polyvore.com/recipes/thing?id=8769455
# Item Doesn't Have Category ID!
#
#
# outfit39
# outfit link: https://www.polyvore.com/26.12.17_27.12.17_giocandoacasaconibambini/set?id=232829830
# item0
# item link: http://www.polyvore.com/bella_freud_star_intarsia_jumper/thing?id=229685323
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229685323) already exists.
#
# item1
# item link: http://www.polyvore.com/side_stripe_drawstring_sweatpants/thing?id=228356560
# item2
# item link: http://www.polyvore.com/ugg_cozy_chenille_sock_womens/thing?id=222729766
# item3
# item link: http://www.polyvore.com/pre-owned_chanel_gold_tone_rhinestone/thing?id=173813199
# item4
# item link: http://www.polyvore.com/iphone_silicone_case_spicy_orange/thing?id=229400247
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229400247) already exists.
#
# item5
# item link: http://www.polyvore.com/messy_bun_studies_ian_david/thing?id=169469022
# Item Doesn't Have Category ID!
#
#
# outfit40
# outfit link: https://www.polyvore.com/6762/set?id=232829158
# item0
# item link: http://www.polyvore.com/boohoo_boutique_lara_embroided_bodycon/thing?id=230049502
# item1
# item link: http://www.polyvore.com/gianvito_rossi_portofino_ankle-strap_sandals/thing?id=226414604
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226414604) already exists.
#
# item2
# item link: http://www.polyvore.com/michael_kors_collection_yasmeen_metallic/thing?id=229266968
# item3
# item link: http://www.polyvore.com/david_yurman_cabochon_black_onyx/thing?id=222417337
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222417337) already exists.
#
# item4
# item link: http://www.polyvore.com/our_favorite_new_holiday_cocktails/thing?id=108895056
# Item Doesn't Have Category ID!
#
#
# outfit41
# outfit link: https://www.polyvore.com/nye_white/set?id=232816501
# item0
# item link: http://www.polyvore.com/ellery_dolly_off_shoulder_dress/thing?id=226388176
# item1
# item link: http://www.polyvore.com/house_fluff_yeti_convertible_oversized/thing?id=225849867
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225849867) already exists.
#
# item2
# item link: http://www.polyvore.com/jimmy_choo_romy_100_glitter/thing?id=229494685
# item3
# item link: http://www.polyvore.com/danse_lente_lorna_mini_leather/thing?id=218088337
# item4
# item link: http://www.polyvore.com/white_lace_choker_necklace/thing?id=211869860
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(211869860) already exists.
#
# item5
# item link: http://www.polyvore.com/pre-owned_mikimoto_18k_white_gold/thing?id=188492527
# item6
# item link: http://www.polyvore.com/adorn_white_shell_pearl_gold/thing?id=228060343
# item7
# item link: http://www.polyvore.com/white_out/thing?id=216923868
# Item Doesn't Have Category ID!
#
#
# outfit42
# outfit link: https://www.polyvore.com/untitled_20460/set?id=232831680
# item0
# item link: http://www.polyvore.com/tibi_metallic_gingham_cotton-blend_flannel/thing?id=217282768
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(217282768) already exists.
#
# item1
# item link: http://www.polyvore.com/alexachung_belted_corduroy_mini_skirt/thing?id=226576173
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226576173) already exists.
#
# item2
# item link: http://www.polyvore.com/black_40_metal_chains_strap/thing?id=229447847
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229447847) already exists.
#
# item3
# item link: http://www.polyvore.com/chanel_velvet_plaid_tartan_small/thing?id=227827897
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227827897) already exists.
#
#
#
# outfit43
# outfit link: https://www.polyvore.com/shein_floral_dress/set?id=232830987
# item0
# item link: http://www.polyvore.com/shein_sheinside_tie_neck_flower/thing?id=229248782
# item1
# item link: http://www.polyvore.com/shein_sheinside_pointed_toe_mid/thing?id=229778150
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229778150) already exists.
#
# item2
# item link: http://www.polyvore.com/apricot_pushlock_closure_plastic_flap/thing?id=179252083
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(179252083) already exists.
#
# item3
# ...
# item1
# item link: http://www.polyvore.com/furla_handbags_cedar_leather_metropolis/thing?id=225646743
# item2
# item link: http://www.polyvore.com/clinique_summer_in_getaway_sheers/thing?id=219659940
# Item Not In Category Women's Fashion!
#
#
# outfit559
# outfit link: https://www.polyvore.com/polypresents_wish_list/set?id=232821316
# item0
# item link: http://www.polyvore.com/chicwish_ultra-cozy_ribbed_neck_knit/thing?id=227163736
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227163736) already exists.
#
# item1
# item link: http://www.polyvore.com/ivory_fur_coat/thing?id=228032366
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228032366) already exists.
#
# item2
# item link: http://www.polyvore.com/madewell_nsf_painted_beck_jeans/thing?id=137518950
# item3
# item link: http://www.polyvore.com/frye_womens_addie_double_zip/thing?id=227608479
# item4
# item link: http://www.polyvore.com/womens_mkf_collection_wild_jungle/thing?id=218880099
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218880099) already exists.
#
# item5
# item link: http://www.polyvore.com/lucky_brand_under_influence_openwork/thing?id=229161526
# item6
# item link: http://www.polyvore.com/lucky_brand_gold-tone_white_stone/thing?id=226823307
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226823307) already exists.
#
# item7
# item link: http://www.polyvore.com/lucky_brand_gold-tone_pave_white/thing?id=226827801
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226827801) already exists.
#
# item8
# item link: http://www.polyvore.com/glidden_premium_gal_hdgwn51d_stone/thing?id=161351080
# Item Doesn't Have Category ID!
#
#
# outfit560
# outfit link: https://www.polyvore.com/let_your_fears_go_you/set?id=232828507
# item0
# item link: http://www.polyvore.com/monsoon_joanna_velvet_print_top/thing?id=223320402
# item1
# item link: http://www.polyvore.com/co_plus_cord_leggings/thing?id=227271729
# item2
# item link: http://www.polyvore.com/calvin_klein_womens_mimette_leather/thing?id=228843169
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228843169) already exists.
#
# item3
# item link: http://www.polyvore.com/womens_rebecca_minkoff_medium_keith/thing?id=220422493
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220422493) already exists.
#
# item4
# item link: http://www.polyvore.com/cartier_small_yellow_gold_diamond/thing?id=228425673
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228425673) already exists.
#
# item5
# item link: http://www.polyvore.com/obsessions_eyeshadow_palette_huda_beauty/thing?id=225148639
# Item Not In Category Women's Fashion!
#
#
# outfit561
# outfit link: https://www.polyvore.com/polypresents_new_years_resolutions/set?id=232820735
# item0
# item link: http://www.polyvore.com/sequins_fringed_midi_party_dress/thing?id=229713738
# item1
# item link: http://www.polyvore.com/giuseppe_zanotti_carrie_crystal/thing?id=225944545
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225944545) already exists.
#
# item2
# item link: http://www.polyvore.com/jimmy_choo_women_finley_glitter/thing?id=227710332
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227710332) already exists.
#
# item3
# item link: http://www.polyvore.com/stephanie_windsor_antiques_womens_art/thing?id=215009382
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(215009382) already exists.
#
# item4
# item link: http://www.polyvore.com/jon_richard_alan_hannah_devoted/thing?id=205820489
# item5
# item link: http://www.polyvore.com/christmas_backdrop_white_snowflake_snow/thing?id=222632952
# Item Not In Category Women's Fashion!
#
#
# outfit562
# outfit link: https://www.polyvore.com/purple_chic/set?id=232830137
# item0
# item link: http://www.polyvore.com/fur_jacket_true/thing?id=225896740
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225896740) already exists.
#
# item1
# item link: http://www.polyvore.com/alexachung_belted_corduroy_mini_skirt/thing?id=226576173
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226576173) already exists.
#
# item2
# item link: http://www.polyvore.com/womens_demonia_camel-203_platform_ankle/thing?id=228873070
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228873070) already exists.
#
# item3
# item link: http://www.polyvore.com/stella_mccartney_tapestry_small_backpack/thing?id=212780384
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(212780384) already exists.
#
# item4
# item link: http://www.polyvore.com/multi_mermaid_foundation_brush/thing?id=216821806
# Item Not In Category Women's Fashion!
#
#
# outfit563
# outfit link: https://www.polyvore.com/untitled_290/set?id=232820218
# item0
# item link: http://www.polyvore.com/her_universe_star_wars_rey/thing?id=170436316
# item1
# item link: http://www.polyvore.com/ugg_womens_kilmer_lace-up_leather/thing?id=217651950
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(217651950) already exists.
#
# item2
# item link: http://www.polyvore.com/star_wars_rebel_alliance_purse/thing?id=228500742
# item3
# item link: http://www.polyvore.com/drop_shadow/thing?id=36389364
# Item Doesn't Have Category ID!
#
#
# outfit564
# outfit link: https://www.polyvore.com/camel_black/set?id=232823187
# item0
# item link: http://www.polyvore.com/demi-lune_leather_shoulder_bag/thing?id=228842934
# item1
# item link: http://www.polyvore.com/preowned_martin_margiela_artisanal_10/thing?id=229150304
# item2
# item link: http://www.polyvore.com/preowned_chanel_autumn_2000_cc/thing?id=189821629
# item3
# item link: http://www.polyvore.com/novica_dried_gourd_cocktail_ring/thing?id=228808404
# item4
# item link: http://www.polyvore.com/new_era_wide_brim_fedora/thing?id=220570990
# Item Not In Category Women's Fashion!
#
#
# outfit565
# outfit link: https://www.polyvore.com/untitled_195/set?id=232830016
# item0
# item link: http://www.polyvore.com/hidden_button_floral_embroidered_shirt/thing?id=227627128
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227627128) already exists.
#
# item1
# item link: http://www.polyvore.com/asymmetric_zipper_rivet_embellished_faux/thing?id=219866472
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219866472) already exists.
#
# item2
# item link: http://www.polyvore.com/topshop_moto_high_waist_ripped/thing?id=224335588
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224335588) already exists.
#
# item3
# item link: http://www.polyvore.com/zimmermann_brogue_flatform/thing?id=218475393
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218475393) already exists.
#
# item4
# item link: http://www.polyvore.com/katy_bag/thing?id=228379707
# item5
# item link: http://www.polyvore.com/asos_pack_silver_jewel_rings/thing?id=224237300
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224237300) already exists.
#
# item6
# item link: http://www.polyvore.com/blaine_round_metal_clear_lens/thing?id=223727870
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223727870) already exists.
#
#
#
# outfit566
# outfit link: https://www.polyvore.com/plain/set?id=232818820
# item0
# item link: http://www.polyvore.com/sale_25_off_90s_knit/thing?id=206342777
# item1
# item link: http://www.polyvore.com/ck_jeans_denim_jacket_90s/thing?id=91634674
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(91634674) already exists.
#
# item2
# item link: http://www.polyvore.com/sale_high_waist_dark_denim/thing?id=83256056
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(83256056) already exists.
#
# item3
# item link: http://www.polyvore.com/cloth_low_trainers_converse/thing?id=166966263
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(166966263) already exists.
#
# item4
# item link: http://www.polyvore.com/denim_caps-lt_blue_w32s47c/thing?id=137349592
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(137349592) already exists.
#
# item5
# item link: http://www.polyvore.com/png_%D1%88%D0%BA%D0%B8/thing?id=74334097
# Item Doesn't Have Category ID!
#
#
# outfit567
# outfit link: https://www.polyvore.com/polypresents_wish_list/set?id=232820557
# item0
# item link: http://www.polyvore.com/hunter_faux_fur-trimmed_down_coat/thing?id=221798919
# item1
# item link: http://www.polyvore.com/beats_dr_dre_urbeats_inear/thing?id=137790594
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(137790594) already exists.
#
# item2
# item link: http://www.polyvore.com/womens_sam_edelman_case_bootie/thing?id=220632441
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220632441) already exists.
#
# item3
# item link: http://www.polyvore.com/burberry_small_dk88_python_top/thing?id=219643102
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219643102) already exists.
#
# item4
# item link: http://www.polyvore.com/calder_cocktail_ring_diamond_accent/thing?id=227886063
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227886063) already exists.
#
# item5
# item link: http://www.polyvore.com/drop_shadow/thing?id=36389368
# Item Doesn't Have Category ID!
#
#
# outfit568
# outfit link: https://www.polyvore.com/untitled_8354/set?id=232831543
# item0
# item link: http://www.polyvore.com/honey_couture_renata_red_off/thing?id=223625161
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223625161) already exists.
#
# item1
# item link: http://www.polyvore.com/juan_carlos_obando_diamond-hem_silk/thing?id=170030102
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(170030102) already exists.
#
# item2
# item link: http://www.polyvore.com/gucci_leather_platform_pump/thing?id=206601548
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(206601548) already exists.
#
# item3
# item link: http://www.polyvore.com/pre-owned_chanel_shoulder_bag/thing?id=140242895
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(140242895) already exists.
#
# item4
# item link: http://www.polyvore.com/dolce_gabbana_dolce_matte_red/thing?id=152070655
# Item Not In Category Women's Fashion!
#
#
# outfit569
# outfit link: https://www.polyvore.com/artemis/set?id=232828207
# item0
# item link: http://www.polyvore.com/cressida_cape_shift_dress/thing?id=228150659
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228150659) already exists.
#
# item1
# item link: http://www.polyvore.com/giuseppe_zanotti_cruel/thing?id=220896060
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220896060) already exists.
#
# item2
# item link: http://www.polyvore.com/womens_rimen_co_pu_leather/thing?id=225925331
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225925331) already exists.
#
# item3
# item link: http://www.polyvore.com/pre-owned_rosantica_necklace/thing?id=216018348
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216018348) already exists.
#
# item4
# item link: http://www.polyvore.com/preowned_2000s_herve_van_der/thing?id=227028855
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227028855) already exists.
#
# item5
# item link: http://www.polyvore.com/deer_origami_pin/thing?id=223121265
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223121265) already exists.
#
# item6
# item link: http://www.polyvore.com/too_faced_pure_gold_face/thing?id=229356080
# Item Not In Category Women's Fashion!
#
#
# outfit570
# outfit link: https://www.polyvore.com/untitled_196/set?id=232830183
# item0
# item link: http://www.polyvore.com/red_cotton_top_jacquemus/thing?id=217601107
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(217601107) already exists.
#
# item1
# item link: http://www.polyvore.com/re_done_originals_grunge_high-rise/thing?id=228543126
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228543126) already exists.
#
# item2
# item link: http://www.polyvore.com/topshop_hot-stuff_platform_boots/thing?id=226821364
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226821364) already exists.
#
# item3
# item link: http://www.polyvore.com/alexander_wang_ball_chain_curb/thing?id=228519937
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228519937) already exists.
#
# item4
# item link: http://www.polyvore.com/maison_margiela_bracelet/thing?id=216910738
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216910738) already exists.
#
# item5
# item link: http://www.polyvore.com/bolo_faux_suede_lariat_choker/thing?id=223154430
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223154430) already exists.
#
# item6
# item link: http://www.polyvore.com/preowned_dolce_gabbana_spring-summer_2001/thing?id=227827702
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227827702) already exists.
#
#
#
# outfit571
# outfit link: https://www.polyvore.com/inspired_nature/set?id=232818392
# item0
# item link: http://www.polyvore.com/room_52_blouse/thing?id=229977146
# item1
# item link: http://www.polyvore.com/tommy_gigi_hadid_harlem_high/thing?id=221221133
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221221133) already exists.
#
# item2
# item link: http://www.polyvore.com/womens_apt_solid_sweater_cable/thing?id=223331082
# item3
# item link: http://www.polyvore.com/senso_womens_sloan_ii_suede/thing?id=221239756
# item4
# item link: http://www.polyvore.com/bueno_veg_tan_satchel_moss/thing?id=225387595
# item5
# item link: http://www.polyvore.com/stila_stay_all_day_waterproof/thing?id=219032923
# Item Not In Category Women's Fashion!
#
#
# outfit572
# outfit link: https://www.polyvore.com/untitled_8340/set?id=232830927
# item0
# item link: http://www.polyvore.com/francesco_scognamiglio_jeweled_crew_neck/thing?id=186602869
# item1
# item link: http://www.polyvore.com/zara_high_heel_leather_sandal/thing?id=102730340
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(102730340) already exists.
#
# item2
# item link: http://www.polyvore.com/row_suede_shoulder_bag/thing?id=172373811
# item3
# item link: http://www.polyvore.com/givenchy_iphone_cover_with_print/thing?id=164320711
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(164320711) already exists.
#
# item4
# item link: http://www.polyvore.com/camera_image_from_styledbyrudy/thing?id=226475969
# Item Doesn't Have Category ID!
#
#
# END!
