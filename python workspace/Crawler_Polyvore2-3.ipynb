# %% [markdown]
# # Polyvore Crawler for Storing to DB

# %%
# %matplotlib inline
import matplotlib
from matplotlib import pyplot as plt
import os
import time
import cv2
import json
import requests
from requests.exceptions import *
import psycopg2
import shutil
from PIL import Image
from lxml import html
from bs4 import BeautifulSoup
from datetime import date, datetime
import numpy as np
from numpy import *
from pylab import *
import pandas
from pandas import Series, DataFrame
import multiprocessing

# %%
# Connect to postgres database
conn = psycopg2.connect(database="fashion", user="michellechen", password="", host="127.0.0.1", port="5432")

print "Opened database successfully"

# Connection cursor to database
cur = conn.cursor()

# Create outfit table
cur.execute('''CREATE TABLE IF NOT EXISTS outfits(
                outfit_id INT PRIMARY KEY NOT NULL,
                link TEXT NOT NULL,
                title TEXT,
                image TEXT,
                author TEXT,
                create_date TEXT,
                views INT,
                likes INT,
                description TEXT,
                similar1 TEXT,
                similar2 TEXT,
                similar3 TEXT,
                similar4 TEXT,
                similar5 TEXT
                )''')

# Create outfit_item table
cur.execute('''CREATE TABLE IF NOT EXISTS outfit_item(
                id TEXT PRIMARY KEY NOT NULL,
                outfit_id INT,
                item_id INT
                )''')

# Create outfit item table
cur.execute('''CREATE TABLE IF NOT EXISTS items(
                item_id INT PRIMARY KEY NOT NULL,
                link TEXT NOT NULL,
                title TEXT,
                image TEXT,
                category1_id INT,
                category1_name TEXT,
                category2_id INT,
                category2_name TEXT,
                category3_id INT,
                category3_name TEXT,
                category4_id INT,
                category4_name TEXT,
                brand TEXT,
                price TEXT,
                likes INT,
                description TEXT,
                keyword1 TEXT,
                keyword2 TEXT,
                keyword3 TEXT,
                keyword4 TEXT,
                keyword5 TEXT,
                keyword6 TEXT
                )''')

conn.commit() 

print "Table created successfully"
# Out:
# Opened database successfully
# Table created successfully

# %%
# Headers
head = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'}

# %%
# Crawl item data with item link
def crawl_item(day, outfit_id, line):
    
    # Initialize
    item_id = 0
    item_link = ""
    item_title = ""
    item_image = ""
    item_category_id = [0, 0, 0, 0]
    item_category_name = ["", "", "", ""]
    item_brand = ""
    item_price = ""
    item_likes = 0
    item_description = ""
    item_keywords = ["", "", "", "", "", ""]
    
    # Item id
    item_id = int(line.split('\n')[0].split('=')[-1])
    #print "item id: " + str(item_id)

    # Item link
    item_link = line.split('context_id')[0] + "id=" + str(item_id)
    print "item link: " + item_link
    
    # Get request response
    while True:
        try:
            res = requests.get(item_link, headers = head)
        except RequestException:
            print "Item Request Connection Error!"
            print "Delay 1 minutes!"
            time.sleep(60) # Delay 60 seconds
        else:
            break
    
    # If Item page is not found
    if res.status_code == 404:
        print "HTTP Response Error " + str(res.status_code)
        print "Item Not Found!"
        return 0
    
    # When http response error
    while res.status_code != 200:
        print "HTTP Response Error " + str(res.status_code)
        time.sleep(3) # Delay 3 seconds
        res = requests.get(item_link, headers = head)
        if res.status_code == 200:
            break

    # Parse html with BeautifulSoup
    soup = BeautifulSoup(res.text, "html.parser")
    
    # Item category
    try:
        category = int(soup.select('.crumb')[0].select('a')[0]['href'].split('=')[-1])
    except ValueError: # Not in category
        print "Item Doesn't Have Category ID!"
        return 0
    else:
        if category != 1: # Not in category "Women's Fashion" 
            print "Item Not In Category Women's Fashion!"
            return 0
        else:
            for index, item in enumerate(soup.select('.crumb')):
                try:
                    item_category_id[index] = int(item.select('a')[0]['href'].split('=')[-1])
                    #print str(item_category_id[index])
                except ValueError:
                    pass
                
                item_category_name[index] = item.select('a')[0].select('span')[0].text       
                #print item_category_name[index]

                # Item brand
                if 'brand=' in item.select('a')[0]['href']:
                    item_brand = item.select('a')[0]['href'].split('brand=')[-1].split('&')[0]
                    #print "item brand: " + item_brand
                    
            # Item title
            item_title = soup.find_all('meta', {'property': 'og:title'})[0]['content']
            #print "item title: " + item_title

            # Item image
            item_image = soup.find_all('meta', {'property': 'og:image'})[0]['content']
            #print "item image: " + item_image
            
            # Save Item image as a jpg file
            while True:
                try: 
                    image_res = requests.get(item_image, stream = True)
                except ConnectionError:
                    print "Image Request Connection Error!"
                    time.sleep(3) # Delay 3 seconds
                else:
                    break
                
            f = open('item_images/' + day + '/' + day + '-' + str(outfit_id) + '-'+ str(item_id) + '.jpg', 'wb')
            shutil.copyfileobj(image_res.raw, f)
            f.close

            # Item price
            try: 
                item_price = soup.select('div.bd')[0].select('.price')[0].text
                #print "item price: " + item_price 
            except IndexError:
                try:
                    item_price = soup.select('div.bd')[0].select('.orig_price')[0].text
                    #print "item price: " + item_price 
                except IndexError:
                    pass
           
            # Item likes
            item_likes = int(soup.find_all('meta', {'property': 'polyvore:saves'})[0]['content'])
            #print "item likes: " + str(item_likes)

            # Item description
            try:
                item_description = soup.select('.tease')[0].text
                #print "item description: " + item_description
            except IndexError:
                pass

            # Item keyword 
            try:
                soup.select('#related_searches')[0].select('a')
            except IndexError:
                pass
            else:
                for index, keyword in enumerate(soup.select('#related_searches')[0].select('a')):
                    if index >= 6:
                        break
                    item_keywords[index] = keyword.text
            #print "item keywords: " + item_keywords
            
           
        
            ############################# Insert item data into database ###############################
            
            # Insert item data into items table
            query = '''INSERT INTO items
                        (item_id, link, title, image, category1_id, category1_name, category2_id, category2_name,
                        category3_id, category3_name, category4_id, category4_name, brand, price, likes,
                        description, keyword1, keyword2, keyword3, keyword4, keyword5, keyword6) 
                        VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);'''
            data = (item_id, item_link, item_title, item_image, item_category_id[0], item_category_name[0], 
                    item_category_id[1], item_category_name[1], item_category_id[2], item_category_name[2],
                    item_category_id[3], item_category_name[3], item_brand, item_price, item_likes, item_description, 
                    item_keywords[0], item_keywords[1], item_keywords[2], item_keywords[3], item_keywords[4], 
                    item_keywords[5])

            try:
                cur.execute(query, data)
            except psycopg2.Error, e:
                print "Item pass!"
                print e.pgerror
                pass

            conn.commit()
            
            
            ########################## Insert outfit-item data into database ###########################

            # Insert outfit-item pairing data into outfit-item table
            pairing_query =  '''INSERT INTO outfit_item (id, outfit_id, item_id) 
                                VALUES(%s, %s, %s);'''
            pairing_data = (str(outfit_id) + "-" + str(item_id), outfit_id, item_id)

            try:
                cur.execute(pairing_query, pairing_data)
            except psycopg2.Error, e:
                print "Outfit-Item pass!"
                print e.pgerror
                pass

            conn.commit()
           
    return 1

# %%
# Crawl outfit data with outfit link
def crawl_outfit (day, line):
  
    # Initialize 
    outfit_link = ""
    outfit_id = 0
    outfit_title = ""
    outfit_image = ""
    outfit_author = ""
    outfit_date = ""
    outfit_views = 0
    outfit_likes = 0
    outfit_description = ""
    outfit_similars = []

    # Get request response
    while True:
        try:
            res = requests.get(line, headers = head)
        except RequestException:
            print "Outfit Request Connection Error!"
            print "Delay 1 minutes!"
            time.sleep(60) # Delay 60 seconds
        else:
            break

    # If outfit page is not found
    if res.status_code == 404:
        # Skip to next outfit
        print "HTTP Response Error " + str(res.status_code)
        print "Outfit Not Found!"
        return
    
    # When http response error
    while res.status_code != 200:
        # Print error code
        print "HTTP Response Error " + str(res.status_code)
        # Delay 3 seconds
        time.sleep(3) 
        # Requests again
        res = requests.get(line, headers = head) 
        if res.status_code == 200:
            break

    # Parse html with BeautifulSoup
    soup = BeautifulSoup(res.text, "html.parser")

    # Outfit link
    outfit_link = line.split('\n')[0]
    print "outfit link: " + outfit_link

    # Outfit id
    outfit_id = int(outfit_link.split('/')[-1].split('=')[-1])
    #print "outfit id: " + str(outfit_id)

    # Outfit title
    outfit_title = soup.find_all('meta', {'property': 'og:title'})[0]['content']
    #print "outfit title: " + outfit_title

    # Outfit image
    outfit_image = soup.find_all('meta', {'property': 'og:image'})[0]['content']
    #print "outfit image: " + outfit_image

    # Save outfit image as a jpg file
    while True:
        try: 
            image_res = requests.get(outfit_image, stream = True)
        except ConnectionError:
            print "Image Request Connection Error!"
            time.sleep(3) # Delay 3 seconds
            continue
        break

    f = open('outfit_images/' + day + '/' + day + '-' + str(outfit_id) + '.jpg', 'wb')
    shutil.copyfileobj(image_res.raw, f)
    f.close

    # Outfit author link
    outfit_author = soup.find_all('meta', {'property': 'polyvore:author'})[0]['content']
    #print "outfit author: " + outfit_author

    # Outfit create time
    outfit_date = day
    #print "outfit create: " + outfit_date

    # Outfit views count
    outfit_views = int(str(soup.select('div.meta')[0].select('div')[-1])[5:-7].split('.')[1].split()[0].replace(',', ''))
    #print "outfit views: " + str(outfit_views)

    # Outfit likes count
    outfit_likes = int(soup.find_all('meta', {'property': 'polyvore:likes'})[0]['content'])
    #print "outfit likes: " + str(outfit_likes)

    # Outfit description
    outfit_description = soup.select('div.bd')[0].select('img')[0]['alt']
    #print "outfit description: " + outfit_description

    # Outfit similar style
    for grid in soup.select('.grid_item.hover_container.type_set.span2w.span2h'):
        for main in grid.select('div.main'):
            outfit_similars.append('http://www.polyvore.com/' + main.select('a')[0]['href'][3:])

    # If similar outfits do not have 5 outfits, append empty one
    if len(outfit_similars) != 5:
        for i in xrange(5 - len(outfit_similars)):
            outfit_similars.append("")

#         for i in xrange(len(outfit_similars)):
#             print "outfit similar " + str(i) + ": " + outfit_similars[i]     



    ############################# Insert outfit data into database #############################    

    # Insert outfit data into outfit table
    outfit_query = '''INSERT INTO outfits 
                        (outfit_id, link, title, image, author, create_date, views, likes, 
                        description, similar1, similar2, similar3, similar4, similar5) 
                        VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);'''
    outfit_data = (outfit_id, outfit_link, outfit_title, outfit_image, outfit_author, outfit_date, 
            outfit_views, outfit_likes, outfit_description, 
            outfit_similars[0], outfit_similars[1], outfit_similars[2], outfit_similars[3], outfit_similars[4])

    try:
        cur.execute(outfit_query, outfit_data)
    except psycopg2.Error, e:
        print "Outfit pass!"
        print e.pgerror
        pass

    conn.commit()


    #################################### Items in the outfit ###################################

    # initialize
    item_count = 0
    item_link = []   

    # Outfit set_item grid
    done = False
    for grid in soup.select('.grid_item.hover_container.type_thing.span1w.span1h'):
        for main in grid.select('div.main'): 

            print "item" + str(item_count)

            item_link.append('http://www.polyvore.com/' + main.select('a')[0]['href'][3:])
            #print "item link " + str(item_count) + ": " + item_link[item_count]

            # Crawl item data, if item is not in category, then next item is not too
            if crawl_item(day, outfit_id, item_link[item_count]) == 0:

                # If first item is not in category, the outfit is not a fashion outfit
                if item_count == 0:

                    print "Remove outfit!"
                    # Delete this outfit row in outfit table
                    outfit_delete = '''DELETE FROM outfits 
                                        WHERE outfit_id = ''' + str(outfit_id) + ''';'''
                    cur.execute(outfit_delete)
                    conn.commit()

                    # Remove this outfit image file
                    os.remove('outfit_images/' + day + '/' + day + '-' + str(outfit_id) + '.jpg')

                done = True
                break # Break the inner for loop

            item_count += 1

#         # If done is true, we do not need to run the next item
        if done: 
            break # Break the outer for loop
       
    return

# %%
# Crawler for all outfits and items in one day
def crawler(day):

    # Create new folder with day name for storing outfit images
    if not os.path.exists('outfit_images/' + day):
        os.makedirs('outfit_images/' + day)

    # Create new folder with day name for storing item images
    if not os.path.exists('item_images/' + day):
        os.makedirs('item_images/' + day)
    
    # Initialize
    outfit_count = 0

    # Open the file
    with open('outfit_links/Today_Outfit_Links_'+ day +'.txt', 'r') as f:
        
        # Read every links in this txt file
        for line in f.readlines():
            
            print "outfit" + str(outfit_count)
            
            if outfit_count != 0 and outfit_count % 50 == 0:
                print "Delay 1 minute!"
                time.sleep(60) # Delay 60 seconds

            # Crawl outfit
            crawl_outfit(day, line)

            print "\n"
            outfit_count += 1
            
    return

# %%
day = '20171229'

crawler(day)

# Close the connection to database
cur.close()
conn.close()

print "END!"
# Out:
# outfit0
# outfit link: https://www.polyvore.com/duke_duchess_sussex_attend_christmas/set?id=232875116
# item0
# item link: http://www.polyvore.com/gebe_maternity_midi_dress_in/thing?id=228377829
# item1
# item link: http://www.polyvore.com/dolce_gabbana_rose-embellished_bar_velvet/thing?id=223120780
# item2
# item link: http://www.polyvore.com/gucci_mini_black_velvet_broadway/thing?id=224428600
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224428600) already exists.
#
# item3
# item link: http://www.polyvore.com/chanel_vintage_cc_fringe_earrings/thing?id=225523402
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225523402) already exists.
#
# item4
# item link: http://www.polyvore.com/belk_co_polished_wedding_band/thing?id=197693013
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(197693013) already exists.
#
# item5
# item link: http://www.polyvore.com/04_carat_gia_cert_oval/thing?id=172370016
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(172370016) already exists.
#
# item6
# item link: http://www.polyvore.com/cgi/thing?id=230210928
# Item Doesn't Have Category ID!
#
#
# outfit1
# outfit link: https://www.polyvore.com/out_this_world_skirt_set/set?id=232862881
# item0
# item link: http://www.polyvore.com/roland_mouret_galaxy_top/thing?id=170573621
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(170573621) already exists.
#
# item1
# item link: http://www.polyvore.com/gucci_sequin-embellished_metallic_jacquard_midi/thing?id=211105937
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(211105937) already exists.
#
# item2
# item link: http://www.polyvore.com/vetements_manolo_blahnik_satin_pumps/thing?id=201229396
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(201229396) already exists.
#
# item3
# item link: http://www.polyvore.com/judith_leiber_couture_slim_slide/thing?id=197680644
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(197680644) already exists.
#
# item4
# item link: http://www.polyvore.com/pre-owned_1950s_blue_moonglow_lucite/thing?id=199265529
# item5
# item link: http://www.polyvore.com/14kt_rose_gold_diamond_star/thing?id=222500017
#
#
# outfit2
# outfit link: https://www.polyvore.com/untitled_369/set?id=232875852
# item0
# item link: http://www.polyvore.com/ann_demeulemeester_oversized_open-knit_sweater/thing?id=219442857
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219442857) already exists.
#
# item1
# item link: http://www.polyvore.com/helmut_lang_stretch_leather_leggings/thing?id=225605173
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225605173) already exists.
#
# item2
# item link: http://www.polyvore.com/giuseppe_zanotti_womens_studded_boot/thing?id=195913011
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(195913011) already exists.
#
# item3
# item link: http://www.polyvore.com/alexander_wang_roxy_round_stud/thing?id=213557068
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(213557068) already exists.
#
# item4
# item link: http://www.polyvore.com/movado_ultra_slim_watch_28mm/thing?id=193389770
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(193389770) already exists.
#
# item5
# item link: http://www.polyvore.com/dannijo_sade_chandelier_earrings/thing?id=227226911
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227226911) already exists.
#
# item6
# item link: http://www.polyvore.com/upgrade_your_chic_text/thing?id=162350264
# Item Doesn't Have Category ID!
#
#
# outfit3
# outfit link: https://www.polyvore.com/flowers/set?id=232878188
# item0
# item link: http://www.polyvore.com/falke_fine_flower_socks/thing?id=83364711
# item1
# item link: http://www.polyvore.com/sienna_miller_floral_ankle_boots/thing?id=97712591
# item2
# item link: http://www.polyvore.com/flidais_parfumerie_lara_natural_perfume/thing?id=146483404
# Item Not In Category Women's Fashion!
#
#
# outfit4
# outfit link: https://www.polyvore.com/polypresents_new_years_resolutions/set?id=232865220
# item0
# item link: http://www.polyvore.com/pierre_balmain_wool_double_breasted/thing?id=228333759
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228333759) already exists.
#
# item1
# item link: http://www.polyvore.com/stretch_cotton_jean_nafice_zip/thing?id=228029010
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228029010) already exists.
#
# item2
# item link: http://www.polyvore.com/gucci_leather_ankle_boot/thing?id=224252042
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224252042) already exists.
#
# item3
# item link: http://www.polyvore.com/givenchy_large_black_red_striped/thing?id=228353522
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228353522) already exists.
#
# item4
# item link: http://www.polyvore.com/light_world_brooch/thing?id=228330907
# item5
# item link: http://www.polyvore.com/cuff_bracelet_lattice_goldtone_avon/thing?id=229490757
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229490757) already exists.
#
# item6
# item link: http://www.polyvore.com/ysl_vinyl_couture_mascara/thing?id=222631718
# Item Not In Category Women's Fashion!
#
#
# outfit5
# outfit link: https://www.polyvore.com/metals/set?id=232874256
# item0
# item link: http://www.polyvore.com/christopher_kane_metallic_ribbed-knit_midi/thing?id=222733989
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222733989) already exists.
#
# item1
# item link: http://www.polyvore.com/marco_de_vincenzo_metallic_ankle/thing?id=220887796
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220887796) already exists.
#
# item2
# item link: http://www.polyvore.com/jeffrey_levinson_womens_elina_clutch/thing?id=227040777
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227040777) already exists.
#
# item3
# item link: http://www.polyvore.com/ana_khouri_womens_lourdes_open/thing?id=215013143
# item4
# item link: http://www.polyvore.com/you_are_loved_light_box/thing?id=227951878
# Item Not In Category Women's Fashion!
#
#
# outfit6
# outfit link: https://www.polyvore.com/lavender/set?id=232868961
# item0
# item link: http://www.polyvore.com/ax_paris_plain_strappy_cropped/thing?id=139861772
# item1
# item link: http://www.polyvore.com/hyein_seo_goddess_faux_fur/thing?id=185102026
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(185102026) already exists.
#
# item2
# item link: http://www.polyvore.com/pastel_violet_high_shine_vinyl/thing?id=140465533
# item3
# item link: http://www.polyvore.com/preowned_tom_ford_for_gucci/thing?id=188330810
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(188330810) already exists.
#
# item4
# item link: http://www.polyvore.com/what_goes_around_comes_chanel/thing?id=138219243
# item5
# item link: http://www.polyvore.com/saint_laurent_rendez-vous_name_tag/thing?id=216758253
# item6
# item link: http://www.polyvore.com/le_skinny_lilac/thing?id=217334877
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(217334877) already exists.
#
#
#
# outfit7
# outfit link: https://www.polyvore.com/ms_moss/set?id=232869772
# item0
# item link: http://www.polyvore.com/jolie_moi_neck_fold_detail/thing?id=212393177
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(212393177) already exists.
#
# item1
# item link: http://www.polyvore.com/zip_up_cropped_jacket/thing?id=228790142
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228790142) already exists.
#
# item2
# item link: http://www.polyvore.com/jessica_simspon_parisah_platform_pumps/thing?id=216028653
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216028653) already exists.
#
# item3
# item link: http://www.polyvore.com/baggallini_moss_avenue_tote/thing?id=229956790
# item4
# item link: http://www.polyvore.com/ray_ban_green_classic_15/thing?id=229559031
# item5
# item link: http://www.polyvore.com/betsey_johnson_stars_crystal_stud/thing?id=229775566
# item6
# item link: http://www.polyvore.com/tropical_17_forest_banana_leaves/thing?id=221690579
#
#
# outfit8
# outfit link: https://www.polyvore.com/flamboyance/set?id=232877973
# item0
# item link: http://www.polyvore.com/jadicted_kimono_black_velvet_long/thing?id=219472921
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219472921) already exists.
#
# item1
# item link: http://www.polyvore.com/ashish_sequin_embellished_faux_fur/thing?id=180167023
# item2
# item link: http://www.polyvore.com/classic_60s_collection_pink_velvet/thing?id=219567540
# item3
# item link: http://www.polyvore.com/truffle_tie_ankle_skinny_heel/thing?id=203016514
# item4
# item link: http://www.polyvore.com/charlotte_olympia_pink_suede_salsa/thing?id=223886502
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223886502) already exists.
#
# item5
# item link: http://www.polyvore.com/wendy_yue_diamond_opal_gemstone/thing?id=220395417
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220395417) already exists.
#
#
#
# outfit9
# outfit link: https://www.polyvore.com/66girls.us/set?id=232874101
# item0
# item link: http://www.polyvore.com/gucci_striped_tweed_skirt/thing?id=224248426
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224248426) already exists.
#
# item1
# item link: http://www.polyvore.com/loeffler_randall_vera_ruffle_block/thing?id=206683761
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(206683761) already exists.
#
# item2
# item link: http://www.polyvore.com/street_level_prism_velvet_wristlet/thing?id=218797515
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218797515) already exists.
#
# item3
# item link: http://www.polyvore.com/mignonne_gavigan_marnie_red_flower/thing?id=229052858
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229052858) already exists.
#
# item4
# item link: http://www.polyvore.com/long_haired_icelandic_sheepskin_rug/thing?id=227626186
# Item Not In Category Women's Fashion!
#
#
# outfit10
# outfit link: https://www.polyvore.com/luulla35/set?id=232873931
# item0
# item link: http://www.polyvore.com/new_simple_strapless_chiffon_evening/thing?id=229883651
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229883651) already exists.
#
# item1
# item link: http://www.polyvore.com/glittering_point_toe_crystal_cinderella/thing?id=215356275
# item2
# item link: http://www.polyvore.com/matt_nat_duma_bifold_wallet/thing?id=229679725
# item3
# item link: http://www.polyvore.com/amethyst_vine_drop_earrings_ct/thing?id=228554713
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228554713) already exists.
#
# item4
# item link: http://www.polyvore.com/kate_spade_new_york_pav%C3%A9/thing?id=226578868
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226578868) already exists.
#
# item5
# item link: http://www.polyvore.com/harpers_bazaar_turkey/thing?id=226743758
# Item Doesn't Have Category ID!
#
#
# outfit11
# outfit link: https://www.polyvore.com/pls_like_are_going_to/set?id=232877552
# item0
# item link: http://www.polyvore.com/dolce_gabbana_shirt/thing?id=213214059
# item1
# item link: http://www.polyvore.com/missoni_lurex_woven_cardigan/thing?id=226947758
# item2
# item link: http://www.polyvore.com/vanilla_chai_exfoliating_body_scrub/thing?id=190387485
# Item Not In Category Women's Fashion!
#
#
# outfit12
# outfit link: https://www.polyvore.com/orange_black/set?id=232861036
# item0
# item link: http://www.polyvore.com/aryeh_orange_floral_sweater_dress/thing?id=230140328
# item1
# item link: http://www.polyvore.com/closed_pori_coat/thing?id=228960703
# item2
# item link: http://www.polyvore.com/fenty_puma_rihanna_womens_patent/thing?id=228970554
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228970554) already exists.
#
# item3
# item link: http://www.polyvore.com/heritage_auctions_special_collections_herm%C3%A8s/thing?id=228601719
# item4
# item link: http://www.polyvore.com/loewe_90x90_anagram_scarf_window/thing?id=215994765
# item5
# item link: http://www.polyvore.com/altea_dal_1973_hat/thing?id=223122402
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223122402) already exists.
#
# item6
# item link: http://www.polyvore.com/ethnic_orange_iphone_case_cover/thing?id=224246832
# item7
# item link: http://www.polyvore.com/ray-ban_aviator_gold_sunglasses_polarized/thing?id=206389885
# item8
# item link: http://www.polyvore.com/red_orange_hair/thing?id=229041403
# item9
# item link: http://www.polyvore.com/60_cool_examples_winter_photography/thing?id=229933163
# Item Doesn't Have Category ID!
#
#
# outfit13
# outfit link: https://www.polyvore.com/looney_tunes/set?id=232876944
# item0
# item link: http://www.polyvore.com/fleur_du_mal_velvet_crop/thing?id=229561746
# item1
# item link: http://www.polyvore.com/philosophy_di_lorenzo_serafini_faux/thing?id=216483009
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216483009) already exists.
#
# item2
# item link: http://www.polyvore.com/adams_mary_jane_kitten_heels/thing?id=228693059
# item3
# item link: http://www.polyvore.com/strathberry_pico_tote_black/thing?id=228069566
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228069566) already exists.
#
# item4
# item link: http://www.polyvore.com/120mm_silver-tone_skinny_hoop_earrings/thing?id=228502769
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228502769) already exists.
#
# item5
# item link: http://www.polyvore.com/stephane_christian_shadowcat_acetate_metal/thing?id=229809641
# item6
# item link: http://www.polyvore.com/mac_lipglass_little_collection/thing?id=228110287
# Item Not In Category Women's Fashion!
#
#
# outfit14
# outfit link: https://www.polyvore.com/make_most_every_moment/set?id=232873219
# item0
# item link: http://www.polyvore.com/bundy_webster_tulip_crop/thing?id=109778223
# item1
# item link: http://www.polyvore.com/fenty_puma_rihanna_tear_away/thing?id=183982876
# item2
# item link: http://www.polyvore.com/no_kaoi_ola_performance_bra/thing?id=229086697
# item3
# item link: http://www.polyvore.com/calvin_klein_underwear_modern_cotton/thing?id=179027931
# item4
# item link: http://www.polyvore.com/zimmermann_lace_up_dress_boot/thing?id=214045837
# item5
# item link: http://www.polyvore.com/louis_vuitton_black_epi_leather/thing?id=229340847
# item6
# item link: http://www.polyvore.com/camera_image_from_boobear1707/thing?id=228691812
# Item Doesn't Have Category ID!
#
#
# outfit15
# outfit link: https://www.polyvore.com/avery_date_outfit/set?id=232876936
# item0
# item link: http://www.polyvore.com/break_away_white_tie_side/thing?id=217408007
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(217408007) already exists.
#
# item1
# item link: http://www.polyvore.com/topshop_moto_gingham_mini_skirt/thing?id=204198761
# item2
# item link: http://www.polyvore.com/womens_steve_madden_bertie_lace-up/thing?id=173219178
# item3
# item link: http://www.polyvore.com/misis_bow_earrings/thing?id=227064932
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227064932) already exists.
#
#
#
# outfit16
# outfit link: https://www.polyvore.com/jade_casual/set?id=232877384
# item0
# item link: http://www.polyvore.com/american_vintage_round_neck_tank/thing?id=55057913
# item1
# item link: http://www.polyvore.com/green_pleated_maxi_skirt/thing?id=70638293
# item2
# item link: http://www.polyvore.com/prada_leather_thong_flat_sandals/thing?id=229885824
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229885824) already exists.
#
# item3
# item link: http://www.polyvore.com/pre-owned_cartier_love_yellow_gold/thing?id=227208942
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227208942) already exists.
#
#
#
# outfit17
# outfit link: https://www.polyvore.com/12.27.17/set?id=232863761
# item0
# item link: http://www.polyvore.com/coach_elvis_print_sweatshirt/thing?id=205133309
# item1
# item link: http://www.polyvore.com/lapel_zipper_pockets_suede_jacket/thing?id=219342486
# item2
# item link: http://www.polyvore.com/ag_matchbox_slim-leg_jeans/thing?id=127379086
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(127379086) already exists.
#
# item3
# item link: http://www.polyvore.com/toms_black_canvas_womens_cordones/thing?id=58567952
# item4
# item link: http://www.polyvore.com/alexander_wang_large_leather_bag/thing?id=50228443
# item5
# item link: http://www.polyvore.com/mizuki_pearl_diamond_wrap_bracelet/thing?id=149091604
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(149091604) already exists.
#
#
#
# outfit18
# outfit link: https://www.polyvore.com/palazzo_prime/set?id=232869533
# item0
# item link: http://www.polyvore.com/plain_mock_neck_lantern_sleeve/thing?id=228165437
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228165437) already exists.
#
# item1
# item link: http://www.polyvore.com/juan_carlos_pajares_emerald_silk/thing?id=193558467
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(193558467) already exists.
#
# item2
# item link: http://www.polyvore.com/stella_mccartney_elyse_star_shoes/thing?id=229566663
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229566663) already exists.
#
# item3
# item link: http://www.polyvore.com/tods_double_crossbody_small/thing?id=229620836
# item4
# item link: http://www.polyvore.com/resin_rhinestone_oval_geometric_earrings/thing?id=228880063
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228880063) already exists.
#
#
#
# outfit19
# outfit link: https://www.polyvore.com/rebuilding_my_wardrobe_changing_everything/set?id=232878361
# item0
# item link: http://www.polyvore.com/mtwtfss_weekday_glam_cardigan_grey/thing?id=45363505
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(45363505) already exists.
#
# item1
# item link: http://www.polyvore.com/ribbed_back_zipper_crop_top/thing?id=143872539
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(143872539) already exists.
#
# item2
# item link: http://www.polyvore.com/skirt_saint_laurent/thing?id=117872033
# item3
# item link: http://www.polyvore.com/row_multi_pouch_shoulder_bag/thing?id=112557148
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(112557148) already exists.
#
# item4
# item link: http://www.polyvore.com/lazy_loafers/thing?id=103343631
#
#
# outfit20
# outfit link: https://www.polyvore.com/untitled_174/set?id=232876281
# item0
# item link: http://www.polyvore.com/alanui_fringed_jacquard-knit_cashmere_cardigan/thing?id=228355152
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228355152) already exists.
#
# item1
# item link: http://www.polyvore.com/calvin_klein_205w39nyc_roll_neck/thing?id=217807780
# item2
# item link: http://www.polyvore.com/olympia_le-tan_kim_teddy_bear/thing?id=225206090
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225206090) already exists.
#
# item3
# item link: http://www.polyvore.com/re_done_high_rise_straight/thing?id=207488747
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(207488747) already exists.
#
# item4
# item link: http://www.polyvore.com/gap_women_slip_on_sneakers/thing?id=201487307
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(201487307) already exists.
#
# item5
# item link: http://www.polyvore.com/strathberry_pico_tote_vanilla/thing?id=228069624
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228069624) already exists.
#
# item6
# item link: http://www.polyvore.com/justine_clenquet_ada_hoop_earrings/thing?id=221061072
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221061072) already exists.
#
#
#
# outfit21
# outfit link: https://www.polyvore.com/hunting_demons_with_isabelle/set?id=232874198
# item0
# item link: http://www.polyvore.com/off_shoulder_long_sleeve_button/thing?id=228968592
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228968592) already exists.
#
# item1
# item link: http://www.polyvore.com/high_waist_denim_cutoffs_with/thing?id=152646422
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(152646422) already exists.
#
# item2
# item link: http://www.polyvore.com/womens_new_mark_maddux_women/thing?id=221041641
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221041641) already exists.
#
# item3
# item link: http://www.polyvore.com/isabelle_lightwood/thing?id=228730359
# Item Doesn't Have Category ID!
#
#
# outfit22
# outfit link: https://www.polyvore.com/golden_day_snowman/set?id=232871987
# item0
# item link: http://www.polyvore.com/orange_neck_wrap_tie_waist/thing?id=221089822
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221089822) already exists.
#
# item1
# item link: http://www.polyvore.com/mes_demoiselles_skittle_silk_jumpsuit/thing?id=224535377
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224535377) already exists.
#
# item2
# item link: http://www.polyvore.com/gianvito_rossi_womens_lace-up_gladiator/thing?id=216825146
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216825146) already exists.
#
# item3
# item link: http://www.polyvore.com/maison_margiela_womens_5ac_large/thing?id=178443766
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(178443766) already exists.
#
# item4
# item link: http://www.polyvore.com/925_silver_gold_plated_synthetic/thing?id=197864909
# item5
# item link: http://www.polyvore.com/mac_amplified_creme_lipstick_colour/thing?id=221677267
# Item Not In Category Women's Fashion!
#
#
# outfit23
# outfit link: https://www.polyvore.com/untitled_291/set?id=232868384
# item0
# item link: http://www.polyvore.com/uniqlo_fall_winter_2017/thing?id=222973996
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222973996) already exists.
#
# item1
# item link: http://www.polyvore.com/zipper_fly_frayed_cut_out/thing?id=229403907
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229403907) already exists.
#
# item2
# item link: http://www.polyvore.com/adidas_womens_cloudfoam_advantage_wht/thing?id=229444813
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229444813) already exists.
#
# item3
# item link: http://www.polyvore.com/flap_minimalist_faux_leather_crossbody/thing?id=229736805
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229736805) already exists.
#
# item4
# item link: http://www.polyvore.com/lc_collection_art_deco_cartier/thing?id=223727754
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223727754) already exists.
#
# item5
# item link: http://www.polyvore.com/loreal_colour_riche_matte_lipstick/thing?id=228482065
# Item Not In Category Women's Fashion!
#
#
# outfit24
# outfit link: https://www.polyvore.com/untitled_1430/set?id=232872305
# item0
# item link: http://www.polyvore.com/pullover_turtleneck_sweater_with_pockets/thing?id=228440640
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228440640) already exists.
#
# item1
# item link: http://www.polyvore.com/dark_wash_distressed_knee_high/thing?id=220643520
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220643520) already exists.
#
# item2
# item link: http://www.polyvore.com/salvatore_ferragamo_women_30mm_crotone/thing?id=223755265
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(223755265) already exists.
#
# item3
# item link: http://www.polyvore.com/chlo%C3%A9_mini_faye_shoulder_bag/thing?id=220325859
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220325859) already exists.
#
# item4
# item link: http://www.polyvore.com/silver_one-size_retro_metal_rings/thing?id=229366080
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229366080) already exists.
#
# item5
# item link: http://www.polyvore.com/links_london_noble_slim_womens/thing?id=226201810
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226201810) already exists.
#
# item6
# item link: http://www.polyvore.com/double_triangle_decorated_fringed_drop/thing?id=228423658
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228423658) already exists.
#
# item7
# item link: http://www.polyvore.com/simple_suede_adjustable_baseball_cap/thing?id=229158316
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229158316) already exists.
#
# item8
# item link: http://www.polyvore.com/phone_cases/thing?id=228602260
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228602260) already exists.
#
# item9
# item link: http://www.polyvore.com/liquid_matte_wifey/thing?id=228678679
# Item Not In Category Women's Fashion!
#
#
# outfit25
# outfit link: https://www.polyvore.com/pastel_goth/set?id=232874289
# item0
# item link: http://www.polyvore.com/romwe_skeleton_knitted_black_jumper/thing?id=115167324
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(115167324) already exists.
#
# item1
# item link: http://www.polyvore.com/black_skeleton_henry_holland_tights/thing?id=46417338
# item2
# item link: http://www.polyvore.com/stay_cute_dyed_distressed_high-waisted/thing?id=90516577
# item3
# item link: http://www.polyvore.com/strawberry_creepers_from_mancphoebe/thing?id=91148098
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(91148098) already exists.
#
# item4
# item link: http://www.polyvore.com/kreepsville_666_skeleton_hand_hair/thing?id=107266232
# item5
# item link: http://www.polyvore.com/takara_tomy_pokemon_black_white/thing?id=97577184
# Item Doesn't Have Category ID!
#
#
# outfit26
# outfit link: https://www.polyvore.com/untitled_257/set?id=232875819
# item0
# item link: http://www.polyvore.com/undercover_skeleton_bride_print_shirt/thing?id=182578067
# item1
# item link: http://www.polyvore.com/lipsy_high_waisted_skinny_jeans/thing?id=217065926
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(217065926) already exists.
#
# item2
# item link: http://www.polyvore.com/balenciaga_charlotte_leather_ankle_boots/thing?id=112423850
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(112423850) already exists.
#
# item3
# item link: http://www.polyvore.com/suzanne_kalan_fireworks_baguette_diamond/thing?id=213440363
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(213440363) already exists.
#
# item4
# item link: http://www.polyvore.com/18k_white_gold_channel_set/thing?id=228217107
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228217107) already exists.
#
# item5
# item link: http://www.polyvore.com/gentle_monster_silver_love_punch/thing?id=218513220
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218513220) already exists.
#
# item6
# item link: http://www.polyvore.com/general_pants_co_your_global/thing?id=228790456
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228790456) already exists.
#
# item7
# item link: http://www.polyvore.com/faux_fur_pom_keyring/thing?id=224344277
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224344277) already exists.
#
# item8
# item link: http://www.polyvore.com/100_pure_mascara/thing?id=207844943
# Item Not In Category Women's Fashion!
#
#
# outfit27
# outfit link: https://www.polyvore.com/oh_bambi/set?id=232870718
# item0
# item link: http://www.polyvore.com/boohoo_petite_sasha_high_neck/thing?id=224884591
# item1
# item link: http://www.polyvore.com/gianvito_rossi_margaux_patent-leather_ankle/thing?id=218208477
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218208477) already exists.
#
# item2
# item link: http://www.polyvore.com/tory_burch_gemini_link_patent/thing?id=218195348
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218195348) already exists.
#
# item3
# item link: http://www.polyvore.com/bandits_womens_long_collar_scarf/thing?id=221039740
# item4
# item link: http://www.polyvore.com/acne_studios_mustang_oval-frame_acetate/thing?id=203341074
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(203341074) already exists.
#
# item5
# item link: http://www.polyvore.com/drop_shadow_effect/thing?id=183759388
# Item Doesn't Have Category ID!
#
#
# outfit28
# outfit link: https://www.polyvore.com/red/set?id=232871580
# item0
# item link: http://www.polyvore.com/elie_saab_heart_shape_neckline/thing?id=228873809
# item1
# item link: http://www.polyvore.com/1365/thing?id=228219026
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228219026) already exists.
#
# item2
# item link: http://www.polyvore.com/badgley_mischka_embellished_convertible_clutch/thing?id=229178802
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229178802) already exists.
#
# item3
# item link: http://www.polyvore.com/womens_kate_spade_new_york/thing?id=229208674
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229208674) already exists.
#
# item4
# item link: http://www.polyvore.com/cluse_negin_minuit_rose_gold/thing?id=229325454
# item5
# item link: http://www.polyvore.com/moon_phases_necklace/thing?id=228134310
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228134310) already exists.
#
# item6
# item link: http://www.polyvore.com/rouge_allure_velvet_luminous_red/thing?id=116350507
# Item Not In Category Women's Fashion!
#
#
# outfit29
# outfit link: https://www.polyvore.com/untitled_382/set?id=232876792
# item0
# item link: http://www.polyvore.com/shape_burgundy_satin_wrap_dress/thing?id=227878823
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227878823) already exists.
#
# item1
# item link: http://www.polyvore.com/fur_coat_black/thing?id=229020879
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229020879) already exists.
#
# item2
# item link: http://www.polyvore.com/womens_steve_madden_insomnia_platform/thing?id=227950898
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227950898) already exists.
#
# item3
# item link: http://www.polyvore.com/lana_reckless_black_diamond_triangle/thing?id=214549666
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(214549666) already exists.
#
# item4
# item link: http://www.polyvore.com/mignonne_gavigan_marnie_red_flower/thing?id=229052858
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229052858) already exists.
#
# item5
# item link: http://www.polyvore.com/fade-frame-4/thing?id=25774949
# Item Doesn't Have Category ID!
#
#
# outfit30
# outfit link: https://www.polyvore.com/untitled_1088/set?id=232874156
# item0
# item link: http://www.polyvore.com/off_shoulder_long_sleeve_button/thing?id=228968592
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228968592) already exists.
#
# item1
# item link: http://www.polyvore.com/womens_seven7_embellished_slim_boot-cut/thing?id=224329397
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224329397) already exists.
#
# item2
# item link: http://www.polyvore.com/sk8_hi_slim_trainers_vans/thing?id=222311252
# item3
# item link: http://www.polyvore.com/lime_crime_strawberry_jam_unicorn/thing?id=211597201
# Item Not In Category Women's Fashion!
#
#
# outfit31
# outfit link: https://www.polyvore.com/faux_fur_fashion_contest/set?id=232862797
# item0
# item link: http://www.polyvore.com/faux_fur_collar_long_sleeve/thing?id=229858565
# item1
# item link: http://www.polyvore.com/balenciaga_ceinture_ankle_boots/thing?id=203488858
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(203488858) already exists.
#
# item2
# item link: http://www.polyvore.com/miu_velvet_tassel_chain_hobo/thing?id=214218137
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(214218137) already exists.
#
# item3
# item link: http://www.polyvore.com/ross-simons_italian_gold_hoop_earrings/thing?id=157317614
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(157317614) already exists.
#
# item4
# item link: http://www.polyvore.com/black_round_frame_metallic_arms/thing?id=212401255
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(212401255) already exists.
#
# item5
# item link: http://www.polyvore.com/lip_gloss/thing?id=227899398
# Item Not In Category Women's Fashion!
#
#
# outfit32
# outfit link: https://www.polyvore.com/hem_geo_dress/set?id=232861367
# item0
# item link: http://www.polyvore.com/shein_sheinside_ruffle_cuff_hem/thing?id=230044463
# item1
# item link: http://www.polyvore.com/shein_sheinside_pu_criss_cross/thing?id=210014591
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(210014591) already exists.
#
# item2
# item link: http://www.polyvore.com/shein_sheinside_suede_shoulder_bag/thing?id=220457739
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220457739) already exists.
#
# item3
# item link: http://www.polyvore.com/shein_sheinside_chain_tassel_drop/thing?id=229194768
# item4
# item link: http://www.polyvore.com/wrights_iron-on_appliques-gold_metallic_stars/thing?id=218012633
# Item Doesn't Have Category ID!
#
#
# outfit33
# outfit link: https://www.polyvore.com/how_embarrassing_to_be_human/set?id=232861459
# item0
# item link: http://www.polyvore.com/nude_high_neck_crop/thing?id=110115832
# item1
# item link: http://www.polyvore.com/victoria_beckham_suede_jacket/thing?id=222160068
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222160068) already exists.
#
# item2
# item link: http://www.polyvore.com/pixie_skirt_ruby/thing?id=85040087
# item3
# item link: http://www.polyvore.com/pumps_chanel/thing?id=206722647
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(206722647) already exists.
#
# item4
# item link: http://www.polyvore.com/miu_small_studded_leather_shoulder/thing?id=13261903
# item5
# item link: http://www.polyvore.com/%E3%81%B5%E3%81%97%E3%81%A0%E3%82%89%E3%81%AA%E5%A5%B3/thing?id=127040404
# Item Doesn't Have Category ID!
#
#
# outfit34
# outfit link: https://www.polyvore.com/untitled_5546/set?id=232875138
# item0
# item link: http://www.polyvore.com/oceana_blue_mixed_knit_cropped/thing?id=211785736
# item1
# item link: http://www.polyvore.com/saint_laurent_geometric_motorcycle_jacket/thing?id=130481012
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(130481012) already exists.
#
# item2
# item link: http://www.polyvore.com/topshop_petite_long_line_rip/thing?id=206747758
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(206747758) already exists.
#
# item3
# item link: http://www.polyvore.com/gianvito_rossi_knitted_over-the-knee_boots/thing?id=217357869
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(217357869) already exists.
#
# item4
# item link: http://www.polyvore.com/michael_kors_ladies_bradshaw_black/thing?id=112899348
# item5
# item link: http://www.polyvore.com/speck_presidio_clear_iphone_case/thing?id=224207178
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224207178) already exists.
#
#
#
# outfit35
# outfit link: https://www.polyvore.com/untitled_1351/set?id=232877763
# item0
# item link: http://www.polyvore.com/hoodie_view_all-sweatshirts-man_zara_united/thing?id=228859817
# item1
# item link: http://www.polyvore.com/moncler_liane_padded_gilet/thing?id=128368635
# item2
# item link: http://www.polyvore.com/chinti_parker_cashmere_track_pants/thing?id=179014420
# item3
# item link: http://www.polyvore.com/adidas_originals_stan_smith_leather/thing?id=130466965
# item4
# item link: http://www.polyvore.com/gucci_black_gg_marmont_matelass/thing?id=219903917
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219903917) already exists.
#
# item5
# item link: http://www.polyvore.com/new_york_yankees_47_mlb/thing?id=219631615
# item6
# item link: http://www.polyvore.com/products_louis_vuitton_keepall_60/thing?id=121370000
# Item Doesn't Have Category ID!
#
#
# outfit36
# outfit link: https://www.polyvore.com/pls/set?id=232877478
# item0
# item link: http://www.polyvore.com/missoni_zig_zag_cardigan/thing?id=218889457
# item1
# item link: http://www.polyvore.com/victoria_tee_legging_set_victorias/thing?id=228527389
# item2
# item link: http://www.polyvore.com/rental_chanel_lambskin_classic_chevron/thing?id=136497044
# item3
# item link: http://www.polyvore.com/early-harvest_raspberry_body_scrub/thing?id=107637508
# Item Not In Category Women's Fashion!
#
#
# outfit37
# outfit link: https://www.polyvore.com/do_even_try/set?id=232875878
# item0
# item link: http://www.polyvore.com/isa_arfen_cotton_cropped_top/thing?id=203858581
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(203858581) already exists.
#
# item1
# item link: http://www.polyvore.com/shein_sheinside_cashew_flowers_print/thing?id=212428180
# item2
# item link: http://www.polyvore.com/converse_all_star_chuck_taylor/thing?id=211000485
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(211000485) already exists.
#
# item3
# item link: http://www.polyvore.com/anne_sisteron_14kt_yellow_gold/thing?id=194614104
# item4
# item link: http://www.polyvore.com/fake_nose_earring_lip_ring/thing?id=214670393
# item5
# item link: http://www.polyvore.com/paint_splash_brush/thing?id=34185460
# Item Doesn't Have Category ID!
#
#
# outfit38
# outfit link: https://www.polyvore.com/1431/set?id=232876155
# item0
# item link: http://www.polyvore.com/river_island_red_lace-up_eyelet/thing?id=229088575
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229088575) already exists.
#
# item1
# item link: http://www.polyvore.com/plain_pu_leather_slit_pencil/thing?id=225115239
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225115239) already exists.
#
# item2
# item link: http://www.polyvore.com/iro_bootev_boot/thing?id=222220689
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(222220689) already exists.
#
# item3
# item link: http://www.polyvore.com/miss_selfridge_black_fishnet_choker/thing?id=224514714
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224514714) already exists.
#
# item4
# item link: http://www.polyvore.com/christmas_elk_horn_headband/thing?id=228038249
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228038249) already exists.
#
# item5
# item link: http://www.polyvore.com/wet_wild_megalast_liquid_catsuit/thing?id=225590603
# Item Not In Category Women's Fashion!
#
#
# outfit39
# outfit link: https://www.polyvore.com/1425/set?id=232875927
# item0
# item link: http://www.polyvore.com/brown_one_size_turtleneck_textured/thing?id=228789543
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228789543) already exists.
#
# item1
# item link: http://www.polyvore.com/gucci_boucl%C3%A9_line_skirt/thing?id=225936274
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225936274) already exists.
#
# item2
# item link: http://www.polyvore.com/moto_grunge_boots/thing?id=225714262
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225714262) already exists.
#
# item3
# item link: http://www.polyvore.com/ardell_faux_mink_lash/thing?id=229345651
# Item Not In Category Women's Fashion!
#
#
# outfit40
# outfit link: https://www.polyvore.com/untitled_292/set?id=232863967
# item0
# item link: http://www.polyvore.com/topshop_moto_mid_blue_denim/thing?id=216566325
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216566325) already exists.
#
# item1
# item link: http://www.polyvore.com/valentino_rockstud_leather_pumps/thing?id=208882449
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(208882449) already exists.
#
# item2
# item link: http://www.polyvore.com/kate_spade_new_york_women/thing?id=228958888
# item3
# item link: http://www.polyvore.com/120mm_silver-tone_skinny_hoop_earrings/thing?id=228502769
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228502769) already exists.
#
# item4
# item link: http://www.polyvore.com/target_ms_denim_top_assorted/thing?id=63653269
#
#
# outfit41
# outfit link: https://www.polyvore.com/travel/set?id=232870712
# item0
# item link: http://www.polyvore.com/isabel_sanchis_layered_flared_gown/thing?id=226809806
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226809806) already exists.
#
# item1
# item link: http://www.polyvore.com/jessica_simpson_palkaya_dress_sandals/thing?id=216534818
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216534818) already exists.
#
# item2
# item link: http://www.polyvore.com/pre-owned_fendi_clutch_bag/thing?id=228359842
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228359842) already exists.
#
# item3
# item link: http://www.polyvore.com/city_love_romantic_things_to/thing?id=219305230
# Item Doesn't Have Category ID!
#
#
# outfit42
# outfit link: https://www.polyvore.com/god_is_within_her_she/set?id=232868986
# item0
# item link: http://www.polyvore.com/this_girl_runs_on_jesus/thing?id=228396244
# item1
# item link: http://www.polyvore.com/nike_power_epic_running_tight/thing?id=196592231
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(196592231) already exists.
#
# item2
# item link: http://www.polyvore.com/free_press_fuzzy_nep_crew/thing?id=229248576
# item3
# item link: http://www.polyvore.com/pre-owned_ugg_australia_shearling_slide/thing?id=218795334
# item4
# item link: http://www.polyvore.com/oliver_peoples_gregory_peck_round/thing?id=216767970
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(216767970) already exists.
#
# item5
# item link: http://www.polyvore.com/nars_nail_polish/thing?id=221271706
# Item Not In Category Women's Fashion!
#
#
# outfit43
# outfit link: https://www.polyvore.com/1432/set?id=232876190
# item0
# item link: http://www.polyvore.com/chicwish_cheer_for_christmas_knit/thing?id=229049739
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229049739) already exists.
#
# item1
# item link: http://www.polyvore.com/banana_republic_olivia_palermo_velvet/thing?id=220175665
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220175665) already exists.
#
# item2
# item link: http://www.polyvore.com/balmain_shoes_acacia_gold_laminated/thing?id=229123599
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229123599) already exists.
#
# item3
# item link: http://www.polyvore.com/artificial_pearl_rhinestone_christmas_elk/thing?id=229570682
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229570682) already exists.
#
# item4
# item link: http://www.polyvore.com/untold_absolu_eau_de_parfum/thing?id=226815544
# Item Not In Category Women's Fashion!
#
#
# outfit44
# outfit link: https://www.polyvore.com/1434/set?id=232876245
# item0
# item link: http://www.polyvore.com/green_marl_made_in_scotland/thing?id=225403797
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225403797) already exists.
#
# item1
# item link: http://www.polyvore.com/chicwish_inviting_sheen_velvet_pleated/thing?id=221576641
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221576641) already exists.
#
# item2
# item link: http://www.polyvore.com/jessica_simpson_eleia_pearl-studded_dress/thing?id=226335229
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226335229) already exists.
#
# item3
# item link: http://www.polyvore.com/christian_dior_diorshow_black_out/thing?id=227870450
# Item Not In Category Women's Fashion!
#
#
# outfit45
# outfit link: https://www.polyvore.com/1435/set?id=232876272
# item0
# item link: http://www.polyvore.com/light_brown_one_size_ribbed/thing?id=228789751
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228789751) already exists.
#
# item1
# item link: http://www.polyvore.com/diane_von_furstenberg_metallic_stripe/thing?id=229126541
# Item pass!
# ...
# DETAIL:  Key (item_id)=(224426564) already exists.
#
# item4
# item link: http://www.polyvore.com/blue_nile_diamond_halo_bracelet/thing?id=224976101
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224976101) already exists.
#
# item5
# item link: http://www.polyvore.com/white_gold_pear_shape_round/thing?id=228704944
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228704944) already exists.
#
#
#
# outfit174
# outfit link: https://www.polyvore.com/tick_tock_past_is_gone/set?id=232866255
# item0
# item link: http://www.polyvore.com/off_shoulder_lace_panel_bandage/thing?id=228243518
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228243518) already exists.
#
# item1
# item link: http://www.polyvore.com/roland_mouret_adrelina_coat/thing?id=224665477
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224665477) already exists.
#
# item2
# item link: http://www.polyvore.com/new_year_party_styles_christian/thing?id=225992047
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225992047) already exists.
#
# item3
# item link: http://www.polyvore.com/elie_saab_enameled_monogram_clutch/thing?id=228873891
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228873891) already exists.
#
# item4
# item link: http://www.polyvore.com/lana_flawless_bond_ring_with/thing?id=212503271
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(212503271) already exists.
#
# item5
# item link: http://www.polyvore.com/sterling_silver_cz_pave_heart/thing?id=144088060
# item6
# item link: http://www.polyvore.com/kenneth_jay_lane_gold_bead/thing?id=226882381
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226882381) already exists.
#
# item7
# item link: http://www.polyvore.com/jennifer_zeuner_jewelry_small_hoop/thing?id=207902264
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(207902264) already exists.
#
# item8
# item link: http://www.polyvore.com/emeraude_toubia_bcg_magazine_january/thing?id=199469068
# Item Doesn't Have Category ID!
#
#
# outfit175
# outfit link: https://www.polyvore.com/day6_like_you/set?id=232873179
# item0
# item link: http://www.polyvore.com/boohoo_fiona_velvet_bardot_crop/thing?id=224398026
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224398026) already exists.
#
# item1
# item link: http://www.polyvore.com/%E3%83%95%E3%82%A1%E3%83%BC%E5%8F%B0%E5%BD%A2%E3%82%B9%E3%82%AB%E3%83%BC%E3%83%88_bubbles_online_store_%E3%83%90%E3%83%96%E3%83%AB%E3%82%B9%E5%85%AC%E5%BC%8F%E9%80%9A%E8%B2%A9%E3%82%B5%E3%82%A4%E3%83%88/thing?id=195024439
# item2
# item link: http://www.polyvore.com/womens_jewel_badgley_mischka_tiffy/thing?id=229904600
# item3
# item link: http://www.polyvore.com/black_night_an_art_print/thing?id=228224512
# Item Doesn't Have Category ID!
#
#
# outfit176
# outfit link: https://www.polyvore.com/polypresents_new_years_resolutions/set?id=232870572
# item0
# item link: http://www.polyvore.com/contrast_hooded_parka/thing?id=222551158
# item1
# item link: http://www.polyvore.com/khlara_grey_jersey_low_back/thing?id=208807422
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(208807422) already exists.
#
# item2
# item link: http://www.polyvore.com/stuart_weitzman_hyper_pointed-toe_velvet/thing?id=174688427
# item3
# item link: http://www.polyvore.com/pre-owned_chanel_timeless_leather_handbag/thing?id=228891439
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228891439) already exists.
#
# item4
# item link: http://www.polyvore.com/womens_treasure_bond_multi_row/thing?id=226633323
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226633323) already exists.
#
# item5
# item link: http://www.polyvore.com/gold_rose_necklace_dainty_charm/thing?id=229427730
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229427730) already exists.
#
# item6
# item link: http://www.polyvore.com/120mm_silver-tone_skinny_hoop_earrings/thing?id=228502769
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228502769) already exists.
#
# item7
# item link: http://www.polyvore.com/peyton_unisex_metal_clear_half-frame/thing?id=228263592
# item8
# item link: http://www.polyvore.com/my_resolutions/thing?id=227041026
# Item Doesn't Have Category ID!
#
#
# outfit177
# outfit link: https://www.polyvore.com/predebut_dance_cover_gashina_sunmi/set?id=232862030
# item0
# item link: http://www.polyvore.com/fenty_puma_rihanna_graphic_black/thing?id=221908917
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221908917) already exists.
#
# item1
# item link: http://www.polyvore.com/basic_black_high_waisted_shorts/thing?id=224714259
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(224714259) already exists.
#
# item2
# item link: http://www.polyvore.com/vans_ward_hi_womens_skate/thing?id=212353784
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(212353784) already exists.
#
# item3
# item link: http://www.polyvore.com/vans_court_side_baseball_hat/thing?id=221251828
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221251828) already exists.
#
# item4
# item link: http://www.polyvore.com/fashion_template_011/thing?id=199336349
# Item Doesn't Have Category ID!
#
#
# outfit178
# outfit link: https://www.polyvore.com/merry_christmas_winter_cristmas/set?id=232867957
# item0
# item link: http://www.polyvore.com/tibi_beige_satin_poplin_cropped/thing?id=209793522
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(209793522) already exists.
#
# item1
# item link: http://www.polyvore.com/rika_velvet_skirt_tfnc/thing?id=227543912
# item2
# item link: http://www.polyvore.com/gianvito_rossi_womens_satin_pumps/thing?id=228377662
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228377662) already exists.
#
# item3
# item link: http://www.polyvore.com/tommy_hilfiger_buckle_leather_crossover/thing?id=228192304
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228192304) already exists.
#
# item4
# item link: http://www.polyvore.com/gold_pcs_cuff_metal_rings/thing?id=226911881
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226911881) already exists.
#
# item5
# item link: http://www.polyvore.com/12.0-13.0_mm_aaa_golden_south/thing?id=220350343
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(220350343) already exists.
#
# item6
# item link: http://www.polyvore.com/apple_iphone_se_leather_case/thing?id=221724666
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221724666) already exists.
#
# item7
# item link: http://www.polyvore.com/gucci_specialized_fit_round-frame_acetate/thing?id=221976422
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(221976422) already exists.
#
# item8
# item link: http://www.polyvore.com/diptyque_vetyverio_eau_de_parfum/thing?id=227064086
# Item Not In Category Women's Fashion!
#
#
# outfit179
# outfit link: https://www.polyvore.com/having_her_brothers_over_for/set?id=232874680
# item0
# item link: http://www.polyvore.com/wood_adrien_longsleeve_blue_white/thing?id=177109359
# item1
# item link: http://www.polyvore.com/adidas_womens_cloudfoam_advantage_wht/thing?id=229444813
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229444813) already exists.
#
# item2
# item link: http://www.polyvore.com/black_chloe_bucket_bag/thing?id=218529567
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(218529567) already exists.
#
# item3
# item link: http://www.polyvore.com/pre-owned_14k_white_gold_1ct/thing?id=228588483
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228588483) already exists.
#
# item4
# item link: http://www.polyvore.com/vogue_article_magazine_layout_text/thing?id=10214079
# Item Doesn't Have Category ID!
#
#
# outfit180
# outfit link: https://www.polyvore.com/pure_gold/set?id=232876268
# item0
# item link: http://www.polyvore.com/shein_sheinside_ruffle_cuff_hem/thing?id=230044454
# item1
# item link: http://www.polyvore.com/loungefly_star_wars_last_jedi/thing?id=228849219
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(228849219) already exists.
#
# item2
# item link: http://www.polyvore.com/oscar_de_la_renta_women/thing?id=227827493
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227827493) already exists.
#
# item3
# item link: http://www.polyvore.com/gold_pcs_cuff_metal_rings/thing?id=226911881
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226911881) already exists.
#
# item4
# item link: http://www.polyvore.com/too_faced_pure_gold_face/thing?id=229356080
# Item Not In Category Women's Fashion!
#
#
# outfit181
# outfit link: https://www.polyvore.com/romwe/set?id=232876875
# item0
# item link: http://www.polyvore.com/contrast_ribbed_trim_balloon_sleeve/thing?id=229496056
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229496056) already exists.
#
# item1
# item link: http://www.polyvore.com/contrast_ribbed_trim_balloon_sleeve/thing?id=228479940
# item2
# item link: http://www.polyvore.com/balmain_black_heavy_cotton_button/thing?id=226851213
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(226851213) already exists.
#
# item3
# item link: http://www.polyvore.com/black_40_metal_chains_strap/thing?id=229447847
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(229447847) already exists.
#
# item4
# item link: http://www.polyvore.com/metallic_flap_chain_bag/thing?id=227430334
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227430334) already exists.
#
# item5
# item link: http://www.polyvore.com/charter_club_gold-tone_green_clear/thing?id=226827794
# item6
# item link: http://www.polyvore.com/silver_triangle_turquoise_elephant_7pcs/thing?id=159379081
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(159379081) already exists.
#
# item7
# item link: http://www.polyvore.com/anna_sui_nail_colour_801/thing?id=227277791
# Item Not In Category Women's Fashion!
#
#
# outfit182
# outfit link: https://www.polyvore.com/problem_with_love_is_you/set?id=232869380
# item0
# item link: http://www.polyvore.com/bauhauslace_knit_sweater_mixxmix/thing?id=163589752
# item1
# item link: http://www.polyvore.com/iro_checked_wool-blend_coat/thing?id=227085813
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227085813) already exists.
#
# item2
# item link: http://www.polyvore.com/faux_suede_tennis_skirt/thing?id=152010141
# item3
# item link: http://www.polyvore.com/25_off_storewide_90s_brown/thing?id=115047722
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(115047722) already exists.
#
# item4
# item link: http://www.polyvore.com/iosselliani_set_pearl_gold_silver/thing?id=2530955
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(2530955) already exists.
#
# item5
# item link: http://www.polyvore.com/mini_spike_charm_necklace_antique/thing?id=114140856
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(114140856) already exists.
#
# item6
# item link: http://www.polyvore.com/succulent_planter/thing?id=77059919
# Item Not In Category Women's Fashion!
#
#
# outfit183
# outfit link: https://www.polyvore.com/golden/set?id=232861840
# item0
# item link: http://www.polyvore.com/matthew_williamson_beige_lacquer_lace/thing?id=170541100
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(170541100) already exists.
#
# item1
# item link: http://www.polyvore.com/ted_baker_pamelia_bobble_matinee/thing?id=227476613
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227476613) already exists.
#
# item2
# item link: http://www.polyvore.com/clarins_pro_palette_eyebrow_kit/thing?id=207032523
# Item Not In Category Women's Fashion!
#
#
# outfit184
# outfit link: https://www.polyvore.com/untitled_538/set?id=232873241
# item0
# item link: http://www.polyvore.com/gucci_logo-print_cotton_shirt/thing?id=210498907
# item1
# item link: http://www.polyvore.com/essie_ultra_distressed_jeans/thing?id=219428163
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219428163) already exists.
#
# item2
# item link: http://www.polyvore.com/gucci_ya126321_unisex_quartz_slim/thing?id=151975799
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(151975799) already exists.
#
# item3
# item link: http://www.polyvore.com/effy_diamond_stud_earrings_ct/thing?id=193734151
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(193734151) already exists.
#
# item4
# item link: http://www.polyvore.com/vv_s1_diamond_glitter_liquid/thing?id=210583693
# Item Not In Category Women's Fashion!
#
#
# outfit185
# outfit link: https://www.polyvore.com/polypresents_new_years_resolutions/set?id=232866152
# item0
# item link: http://www.polyvore.com/ringad_sammetstopp_129/thing?id=219407357
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(219407357) already exists.
#
# item1
# item link: http://www.polyvore.com/miss_selfridge_black_button_through/thing?id=175772826
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(175772826) already exists.
#
# item2
# item link: http://www.polyvore.com/dolce_gabbana_embellished_leather_derby/thing?id=215739305
# item3
# item link: http://www.polyvore.com/my_resolutions/thing?id=227041026
# Item Doesn't Have Category ID!
#
#
# outfit186
# outfit link: https://www.polyvore.com/untitled_215/set?id=232874903
# item0
# item link: http://www.polyvore.com/mugler_goddess_pleated_lam%C3%A9_gown/thing?id=227015232
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(227015232) already exists.
#
# item1
# item link: http://www.polyvore.com/giuseppe_zanotti_cruel/thing?id=225845123
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(225845123) already exists.
#
# item2
# item link: http://www.polyvore.com/studded_four_ring_clutch/thing?id=224364135
# item3
# item link: http://www.polyvore.com/pave_classica_effy_diamond_filigree/thing?id=191215821
# Item pass!
# ERROR:  duplicate key value violates unique constraint "items_pkey"
# DETAIL:  Key (item_id)=(191215821) already exists.
#
# item4
# item link: http://www.polyvore.com/rhodium_plated_crystal_simulated_grey/thing?id=218288225
# item5
# item link: http://www.polyvore.com/fred_leighton_one-of-a-kind_19th_century/thing?id=228186298
# item6
# item link: http://www.polyvore.com/dreamy_matte_liquid_lipstick_kernel/thing?id=228848059
# Item Not In Category Women's Fashion!
#
#
# END!
